# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 2.6

r = 1/10

#三角形の一辺
s = 0.3

#穴シフト
r = 1

#計算する固有周波数の数
num_bands = 10

#メッシュの細かさ
resolution = 64

h = 20

#-------------------------------------------------------------------#

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

#三角形
s_param = s/(np.sqrt(3))

# ▷
tri1 = [
        mp.Vector3(-1,-1)*s_param,
        mp.Vector3(1,0)*s_param,
        mp.Vector3(0,1)*s_param
      ]

# ◁
tri2 = [
        mp.Vector3(1,1)*s_param,
        mp.Vector3(-1,0)*s_param,
        mp.Vector3(0,-1)*s_param
      ]

#構造
geometry = [
            mp.Block(material=mp.Medium(epsilon=n_si**2),
                        size=mp.Vector3(mp.inf, mp.inf)),

            mp.Prism(tri1, center=mp.Vector3(1/3, 1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),
            
            mp.Prism(tri2, center=mp.Vector3(1/3, 0)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri1, center=mp.Vector3(0, -1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri2, center=mp.Vector3(-1/3, -1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri1, center=mp.Vector3(-1/3, 0)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),
    
            mp.Prism(tri2, center=mp.Vector3(0, 1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2))
    
           ]


#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(8, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.333333,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.160128,0.160128,-10)
#           (0.506538,0.333333,-10)
#           (0.333333,0.506538,-10)
#      prism, center = (0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.506538,0.173205,-10)
#           (0.160128,0,-10)
#           (0.333333,-0.173205,-10)
#      prism, center = (0,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.506538,-10)
#           (0.173205,-0.333333,-10)
#           (0,-0.160128,-10)
#      prism, center = (-0.333333,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.160128,-0.160128,-10)
#           (-0.506538,-0.333333,-10)
#           (-0.333333,-0.506538,-10)
#      prism, center = (-0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.506538,-0.173205,-10)
#           (-0.160128,0,-10)
#           (-0.333333,0.173205,-10)
#      prism, center = (0,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.506538,-10)
#           (-0.173205,0.333333,-10)
#           (0,0.160128,-10)
# Geometric object tree has depth 5 and 103 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 28 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.48148148148148145, 0.037037037037037035, 0.0>
#   Vector3<0.46296296296296297, 0.07407407407407407, 0.0>
#   Vector3<0.4444444444444444, 0.1111111111111111, 0.0>
#   Vector3<0.42592592592592593, 0.14814814814814814, 0.0>
#   Vector3<0.4074074074074074, 0.18518518518518517, 0.0>
#   Vector3<0.38888888888888884, 0.2222222222222222, 0.0>
#   Vector3<0.37037037037037035, 0.25925925925925924, 0.0>
#   Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.2962962962962963, 0.2962962962962963, 0.0>
#   Vector3<0.25925925925925924, 0.25925925925925924, 0.0>
#   Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
#   Vector3<0.18518518518518517, 0.18518518518518517, 0.0>
#   Vector3<0.14814814814814814, 0.14814814814814814, 0.0>
#   Vector3<0.1111111111111111, 0.1111111111111111, 0.0>
#   Vector3<0.07407407407407407, 0.07407407407407407, 0.0>
#   Vector3<0.037037037037037035, 0.037037037037037035, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.14435982704162598
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 27 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.460694, 0.460726, 0.523268, 0.523296, 0.52335, 0.523357, 0.815032, 0.815055, 0.829091
# elapsed time for k point: 0.42326807975769043
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 29 iterations.
# tmfreqs:, 2, 0.0555556, 0, 0, 0.06415, 0.0281165, 0.454323, 0.45673, 0.510052, 0.51637, 0.537613, 0.541588, 0.802063, 0.807348, 0.833812
# elapsed time for k point: 0.4254474639892578
# solve_kpoint (0.111111,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 13 iterations.
# tmfreqs:, 3, 0.111111, 0, 0, 0.1283, 0.0562244, 0.436438, 0.44899, 0.497994, 0.521757, 0.552869, 0.56458, 0.781889, 0.794303, 0.836614
# elapsed time for k point: 0.23448729515075684
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# t
# solve_kpoint (0.259259,0.259259,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tmfreqs:, 21, 0.259259, 0.259259, 0, 0.518519, 0.226459, 0.326573, 0.326585, 0.547657, 0.547667, 0.63423, 0.695004, 0.695012, 0.740692, 0.816431
# elapsed time for k point: 0.09447145462036133
# solve_kpoint (0.222222,0.222222,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tmfreqs:, 22, 0.222222, 0.222222, 0, 0.444444, 0.194307, 0.347416, 0.34743, 0.536027, 0.536037, 0.663242, 0.670374, 0.670381, 0.749227, 0.83618
# elapsed time for k point: 0.1361830234527588
# solve_kpoint (0.185185,0.185185,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 78 iterations.
# tmfreqs:, 23, 0.185185, 0.185185, 0, 0.37037, 0.162056, 0.369479, 0.369494, 0.526059, 0.526069, 0.644434, 0.64444, 0.691796, 0.758838, 0.816539
# elapsed time for k point: 0.9370014667510986
# solve_kpoint (0.148148,0.148148,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tmfreqs:, 24, 0.148148, 0.148148, 0, 0.296296, 0.129728, 0.392274, 0.392291, 0.517991, 0.518002, 0.618088, 0.618093, 0.719818, 0.769467, 0.822272
# elapsed time for k point: 0.11050009727478027
# solve_kpoint (0.111111,0.111111,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# tmfreqs:, 25, 0.111111, 0.111111, 0, 0.222222, 0.0973437, 0.415117, 0.415137, 0.512201, 0.512213, 0.591882, 0.591884, 0.747204, 0.781038, 0.827302
# elapsed time for k point: 0.1195826530456543
# solve_kpoint (0.0740741,0.0740741,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tmfreqs:, 26, 0.0740741, 0.0740741, 0, 0.148148, 0.064918, 0.436686, 0.436711, 0.509523, 0.509536, 0.566407, 0.566407, 0.773746, 0.793416, 0.831075
# elapsed time for k point: 0.12571024894714355
# solve_kpoint (0.037037,0.037037,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# tmfreqs:, 27, 0.037037, 0.037037, 0, 0.0740741, 0.0324656, 0.45382, 0.45385, 0.512092, 0.512106, 0.542733, 0.542738, 0.798695, 0.806177, 0.832455
# elapsed time for k point: 0.13677501678466797
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 15 iterations.
# tmfreqs:, 28, 0, 0, 0, 0, 0, 0.460694, 0.460726, 0.523268, 0.523296, 0.52335, 0.523357, 0.815032, 0.815055, 0.829077
# elapsed time for k point: 0.18670272827148438
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.29030851311798367 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2519112865560556 at Vector3<0.5, 0.0, 0.0> to 0.46069377490279884 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.29032631042369417 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.46072624686142755 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4558686003331052 at Vector3<0.5, 0.0, 0.0> to 0.5751030964671612 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5095359036759742 at Vector3<0.07407407407407407, 0.07407407407407407, 0.0> to 0.6370814539597393 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5233498688237372 at Vector3<0.0, 0.0, 0.0> to 0.663241856292049 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
# Band 7 range: 0.5233570611215385 at Vector3<0.0, 0.0, 0.0> to 0.7269352273399242 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 0.6703810632126069 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0> to 0.8150321247637337 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 0.705530994096053 at Vector3<0.4444444444444444, 0.0, 0.0> to 0.8150547775982551 at Vector3<0.0, 0.0, 0.0>
# Band 10 range: 0.7837069285381819 at Vector3<0.5, 0.0, 0.0> to 0.850045830879146 at Vector3<0.3333333333333333, 0.0, 0.0>
# total elapsed time for run: 6.06176233291626
# done
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.333333,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.160128,0.160128,-10)
#           (0.506538,0.333333,-10)
#           (0.333333,0.506538,-10)
#      prism, center = (0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.506538,0.173205,-10)
#           (0.160128,0,-10)
#           (0.333333,-0.173205,-10)
#      prism, center = (0,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.506538,-10)
#           (0.173205,-0.333333,-10)
#           (0,-0.160128,-10)
#      prism, center = (-0.333333,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.160128,-0.160128,-10)
#           (-0.506538,-0.333333,-10)
#           (-0.333333,-0.506538,-10)
#      prism, center = (-0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.506538,-0.173205,-10)
#           (-0.160128,0,-10)
#           (-0.333333,0.173205,-10)
#      prism, center = (0,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.506538,-10)
#           (-0.173205,0.333333,-10)
#           (0,0.160128,-10)
# Geometric object tree has depth 5 and 103 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 28 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.48148148148148145, 0.037037037037037035, 0.0>
#   Vector3<0.46296296296296297, 0.07407407407407407, 0.0>
#   Vector3<0.4444444444444444, 0.1111111111111111, 0.0>
#   Vector3<0.42592592592592593, 0.14814814814814814, 0.0>
#   Vector3<0.4074074074074074, 0.18518518518518517, 0.0>
#   Vector3<0.38888888888888884, 0.2222222222222222, 0.0>
#   Vector3<0.37037037037037035, 0.25925925925925924, 0.0>
#   Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.2962962962962963, 0.2962962962962963, 0.0>
#   Vector3<0.25925925925925924, 0.25925925925925924, 0.0>
#   Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
#   Vector3<0.18518518518518517, 0.18518518518518517, 0.0>
#   Vector3<0.14814814814814814, 0.14814814814814814, 0.0>
#   Vector3<0.1111111111111111, 0.1111111111111111, 0.0>
#   Vector3<0.07407407407407407, 0.07407407407407407, 0.0>
#   Vector3<0.037037037037037035, 0.037037037037037035, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.16962623596191406
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 22 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.518241, 0.518372, 0.519557, 0.519773, 0.624586, 0.625263, 0.845841, 0.861692, 0.974796
# elapsed time for k point: 0.3099033832550049
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# tefreqs:, 19, 0.333333, 0.333333, 0, 0.666667, 0.315184, 0.315318, 0.316395, 0.638802, 0.639186, 0.643362, 0.769907, 0.773458, 0.773939, 0.943541
# elapsed time for k point: 0.11193299293518066
# solve_kpoint (0.296296,0.296296,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# tefreqs:, 20, 0.296296, 0.296296, 0, 0.592593, 0.282101, 0.333628, 0.333746, 0.62316, 0.62354, 0.67529, 0.765881, 0.766412, 0.777746, 0.946029
# elapsed time for k point: 0.11040472984313965
# solve_kpoint (0.259259,0.259259,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 82 iterations.
# tefreqs:, 21, 0.259259, 0.259259, 0, 0.518519, 0.247381, 0.354325, 0.354425, 0.608572, 0.608948, 0.706833, 0.750872, 0.751377, 0.786827, 0.946683
# elapsed time for k point: 0.9406173229217529
# solve_kpoint (0.222222,0.222222,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 22, 0.222222, 0.222222, 0, 0.444444, 0.212386, 0.376783, 0.376867, 0.595166, 0.595532, 0.730885, 0.731383, 0.737555, 0.797079, 0.951618
# elapsed time for k point: 0.12089133262634277
# solve_kpoint (0.185185,0.185185,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 23, 0.185185, 0.185185, 0, 0.37037, 0.177205, 0.400537, 0.400606, 0.582949, 0.583297, 0.708299, 0.708784, 0.766846, 0.808316, 0.956828
# elapsed time for k point: 0.12455344200134277
# solve_kpoint (0.148148,0.148148,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 24, 0.148148, 0.148148, 0, 0.296296, 0.141894, 0.425125, 0.425181, 0.571746, 0.572064, 0.684924, 0.685421, 0.793797, 0.820373, 0.962058
# elapsed time for k point: 0.12570548057556152
# solve_kpoint (0.111111,0.111111,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# tefreqs:, 25, 0.111111, 0.111111, 0, 0.222222, 0.106491, 0.450038, 0.450084, 0.561049, 0.561318, 0.662474, 0.663004, 0.816679, 0.833259, 0.966952
# elapsed time for k point: 0.13364052772521973
# solve_kpoint (0.0740741,0.0740741,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# tefreqs:, 26, 0.0740741, 0.0740741, 0, 0.148148, 0.0710264, 0.474637, 0.474672, 0.549777, 0.549975, 0.64306, 0.643646, 0.833052, 0.846775, 0.971048
# elapsed time for k point: 0.12552165985107422
# solve_kpoint (0.037037,0.037037,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# tefreqs:, 27, 0.037037, 0.037037, 0, 0.0740741, 0.0355226, 0.498021, 0.498048, 0.536236, 0.536354, 0.629498, 0.630146, 0.842585, 0.857636, 0.973816
# elapsed time for k point: 0.13325834274291992
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 10 iterations.
# tefreqs:, 28, 0, 0, 0, 0, 0, 0.518241, 0.518372, 0.519557, 0.519773, 0.624586, 0.625263, 0.845841, 0.861692, 0.974796
# elapsed time for k point: 0.13247060775756836
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3151840882689833 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2748645957119621 at Vector3<0.5, 0.0, 0.0> to 0.5182414033746305 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3163952566137437 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.5183722653044116 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5195573803410659 at Vector3<0.0, 0.0, 0.0> to 0.6388024061840675 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5197728108893596 at Vector3<0.0, 0.0, 0.0> to 0.7061680222129348 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.6245858461013938 at Vector3<0.0, 0.0, 0.0> to 0.7308848638566476 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
# Band 7 range: 0.6252628744975597 at Vector3<0.0, 0.0, 0.0> to 0.7701947022282478 at Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
# Band 8 range: 0.7375548733068215 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0> to 0.8458410259240943 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 0.7553322231496448 at Vector3<0.4444444444444444, 0.0, 0.0> to 0.8616919712955339 at Vector3<0.0, 0.0, 0.0>
# Band 10 range: 0.9356242044712181 at Vector3<0.5, 0.0, 0.0> to 0.9778223441855864 at Vector3<0.3333333333333333, 0.0, 0.0>
# Gap from band 3 (0.5183722653044116) to band 4 (0.5195573803410659), 0.2283613425295882%
# Gap from band 9 (0.8616919712955339) to band 10 (0.9356242044712181), 8.22695908182588%
# total elapsed time for run: 5.5718982219696045
# done

# %%
#import csv
#with open(out_dir / 'epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.figure(figsize=(12,9))
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.76, mean 5.2051, harm. mean 2.82058, 78.7598% > 1, 73.0052% "fill"

# %%
tm_freqs.max()
# Out:
# 0.850045830879146

# %%
fig, ax = plt.subplots(figsize=(8,6))

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
hfields = []

def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,
          get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=64, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

plt.figure(figsize=(15,10))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.333333,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.160128,0.160128,-10)
#           (0.506538,0.333333,-10)
#           (0.333333,0.506538,-10)
#      prism, center = (0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.506538,0.173205,-10)
#           (0.160128,0,-10)
#           (0.333333,-0.173205,-10)
#      prism, center = (0,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.506538,-10)
#           (0.173205,-0.333333,-10)
#           (0,-0.160128,-10)
#      prism, center = (-0.333333,-0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.160128,-0.160128,-10)
#           (-0.506538,-0.333333,-10)
#           (-0.333333,-0.506538,-10)
#      prism, center = (-0.333333,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.506538,-0.173205,-10)
#           (-0.160128,0,-10)
#           (-0.333333,0.173205,-10)
#      prism, center = (0,0.333333,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.506538,-10)
#           (-0.173205,0.333333,-10)
#           (0,0.160128,-10)
# Geometric object tree has depth 5 and 103 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 28 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.48148148148148145, 0.037037037037037035, 0.0>
#   Vector3<0.46296296296296297, 0.07407407407407407, 0.0>
#   Vector3<0.4444444444444444, 0.1111111111111111, 0.0>
#   Vector3<0.42592592592592593, 0.14814814814814814, 0.0>
#   Vector3<0.4074074074074074, 0.18518518518518517, 0.0>
#   Vector3<0.38888888888888884, 0.2222222222222222, 0.0>
#   Vector3<0.37037037037037035, 0.25925925925925924, 0.0>
#   Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.2962962962962963, 0.2962962962962963, 0.0>
#   Vector3<0.25925925925925924, 0.25925925925925924, 0.0>
#   Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
#   Vector3<0.18518518518518517, 0.18518518518518517, 0.0>
#   Vector3<0.14814814814814814, 0.14814814814814814, 0.0>
#   Vector3<0.1111111111111111, 0.1111111111111111, 0.0>
#   Vector3<0.07407407407407407, 0.07407407407407407, 0.0>
#   Vector3<0.037037037037037035, 0.037037037037037035, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.1021723747253418
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 24 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.518241, 0.518372, 0.519557, 0.519773, 0.624586, 0.625263, 0.845841, 0.861692, 0.974796
# elapsed time for k point: 0.30994176864624023
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 0.828975 + 0.559286i; max ampl. = 2.01865
# Fixing h-field (band 3) phase by -0.991802 + -0.127785i; max ampl. = 1.92959
# Fixing h-field (band 4) phase by 0.764793 + 0.644277i; max ampl. = 2.31178
# Fixing h-field (band 5) phase by -0.91523 + -0.402931i; max ampl. = 2.02195
# Fixing h-field (band 6) phase by -0.836564 + -0.547869i; max ampl. = 3.61383
# Fixing h-field (band 7) phase by -0.54305 + 0.839701i; max ampl. = 3.12362
# Fixing h-field (band 8) phase by -0.379983 + 0.924994i; max ampl. = 1.6955
# Fixing h-field (band 9) phase by 0.925264 + -0.379325i; max ampl. = 3.13225
# Fixing h-field (band 10) phase by 0.959015 + -0.283357i; max ampl. = 2.62944
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 15 iterations.
# tefreqs:, 2, 0.0555556, 0, 0, 0.06415, 0.0307188, 0.499147, 0.502895, 0.531543, 0.537022, 0.627675, 0.62939, 0.843329, 0.858636, 0.974624
# elapsed time for k point: 0.20594167709350586
# solve_kpoint (0.111111,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after
0.222222,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tefreqs:, 16, 0.388889, 0.222222, 0, 0.61864, 0.293411, 0.294255, 0.365229, 0.591322, 0.663669, 0.668065, 0.764823, 0.76604, 0.770079, 0.939202
# elapsed time for k point: 0.10591554641723633
# solve_kpoint (0.37037,0.259259,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tefreqs:, 17, 0.37037, 0.259259, 0, 0.632889, 0.299892, 0.300846, 0.348838, 0.607064, 0.655305, 0.659703, 0.767411, 0.769243, 0.7732, 0.940472
# elapsed time for k point: 0.11561226844787598
# solve_kpoint (0.351852,0.296296,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 6 iterations.
# tefreqs:, 18, 0.351852, 0.296296, 0, 0.648941, 0.307196, 0.308247, 0.332147, 0.622982, 0.64707, 0.651449, 0.770195, 0.770805, 0.774486, 0.94192
# elapsed time for k point: 0.1450662612915039
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# tefreqs:, 19, 0.333333, 0.333333, 0, 0.666667, 0.315184, 0.315318, 0.316395, 0.638802, 0.639186, 0.643362, 0.769907, 0.773458, 0.773939, 0.943541
# elapsed time for k point: 0.14756202697753906
# solve_kpoint (0.296296,0.296296,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 7 iterations.
# tefreqs:, 20, 0.296296, 0.296296, 0, 0.592593, 0.282101, 0.333628, 0.333746, 0.62316, 0.62354, 0.67529, 0.765881, 0.766412, 0.777746, 0.946029
# elapsed time for k point: 0.16999578475952148
# solve_kpoint (0.259259,0.259259,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 82 iterations.
# tefreqs:, 21, 0.259259, 0.259259, 0, 0.518519, 0.247381, 0.354325, 0.354425, 0.608572, 0.608948, 0.706833, 0.750872, 0.751377, 0.786827, 0.946683
# elapsed time for k point: 1.1186926364898682
# solve_kpoint (0.222222,0.222222,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 22, 0.222222, 0.222222, 0, 0.444444, 0.212386, 0.376783, 0.376867, 0.595166, 0.595532, 0.730885, 0.731383, 0.737555, 0.797079, 0.951618
# elapsed time for k point: 0.1430509090423584
# solve_kpoint (0.185185,0.185185,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 23, 0.185185, 0.185185, 0, 0.37037, 0.177205, 0.400537, 0.400606, 0.582949, 0.583297, 0.708299, 0.708784, 0.766846, 0.808316, 0.956828
# elapsed time for k point: 0.14820003509521484
# solve_kpoint (0.148148,0.148148,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 8 iterations.
# tefreqs:, 24, 0.148148, 0.148148, 0, 0.296296, 0.141894, 0.425125, 0.425181, 0.571746, 0.572064, 0.684924, 0.685421, 0.793797, 0.820373, 0.962058
# elapsed time for k point: 0.14525461196899414
# solve_kpoint (0.111111,0.111111,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# tefreqs:, 25, 0.111111, 0.111111, 0, 0.222222, 0.106491, 0.450038, 0.450084, 0.561049, 0.561318, 0.662474, 0.663004, 0.816679, 0.833259, 0.966952
# elapsed time for k point: 0.14434146881103516
# solve_kpoint (0.0740741,0.0740741,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 9 iterations.
# tefreqs:, 26, 0.0740741, 0.0740741, 0, 0.148148, 0.0710264, 0.474637, 0.474672, 0.549777, 0.549975, 0.64306, 0.643646, 0.833052, 0.846775, 0.971048
# elapsed time for k point: 0.16404199600219727
# solve_kpoint (0.037037,0.037037,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# tefreqs:, 27, 0.037037, 0.037037, 0, 0.0740741, 0.0355226, 0.498021, 0.498048, 0.536236, 0.536354, 0.629498, 0.630146, 0.842585, 0.857636, 0.973816
# elapsed time for k point: 0.18248748779296875
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 10 iterations.
# tefreqs:, 28, 0, 0, 0, 0, 0, 0.518241, 0.518372, 0.519557, 0.519773, 0.624586, 0.625263, 0.845841, 0.861692, 0.974796
# elapsed time for k point: 0.14653468132019043
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by -1 + -8.27161e-06i; max ampl. = 2.01865
# Fixing h-field (band 3) phase by -8.27161e-06 + 1i; max ampl. = 1.92959
# Fixing h-field (band 4) phase by 1 + 8.27161e-06i; max ampl. = 2.31182
# Fixing h-field (band 5) phase by 8.27161e-06 + -1i; max ampl. = 2.02194
# Fixing h-field (band 6) phase by -1 + -8.27161e-06i; max ampl. = 3.61382
# Fixing h-field (band 7) phase by 8.27161e-06 + -1i; max ampl. = 3.12359
# Fixing h-field (band 8) phase by -8.27161e-06 + 1i; max ampl. = 1.69545
# Fixing h-field (band 9) phase by 1 + 8.27161e-06i; max ampl. = 3.13226
# Fixing h-field (band 10) phase by 8.27161e-06 + -1i; max ampl. = 2.62742
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.31518408812175197 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2748645957119618 at Vector3<0.5, 0.0, 0.0> to 0.5182414035993607 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.31639525693857556 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.5183722656464852 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5195573813471895 at Vector3<0.0, 0.0, 0.0> to 0.6388024061556942 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5197728110756799 at Vector3<0.0, 0.0, 0.0> to 0.7061680222129346 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.6245858465722804 at Vector3<0.0, 0.0, 0.0> to 0.7308848638622144 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
# Band 7 range: 0.6252628751459139 at Vector3<0.0, 0.0, 0.0> to 0.7701947022282465 at Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
# Band 8 range: 0.7375548733183015 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0> to 0.8458410356881244 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 0.7553322231496471 at Vector3<0.4444444444444444, 0.0, 0.0> to 0.8616919696359151 at Vector3<0.0, 0.0, 0.0>
# Band 10 range: 0.9356242044712373 at Vector3<0.5, 0.0, 0.0> to 0.9778223441856025 at Vector3<0.3333333333333333, 0.0, 0.0>
# Gap from band 3 (0.5183722656464852) to band 4 (0.5195573813471895), 0.2283614701896196%
# Gap from band 9 (0.8616919696359151) to band 10 (0.9356242044712373), 8.226959274102041%
# total elapsed time for run: 6.395114421844482
# done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8f3346093a9b> in <module>
#      19
#      20 for i, f in enumerate(converted):
# ---> 21     plt.subplot(331 + i)
#      22     plt.contour(converted_eps.T, cmap='binary')
#      23     plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 12, not 0

# %%
#THz表示
a = 820
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)



fig, ax = plt.subplots(figsize=(8,6))

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
