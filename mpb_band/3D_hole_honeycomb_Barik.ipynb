# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 3.48

#slab厚さ
h = 0.5

#三角形の一辺
s = 0.3

#穴シフト
r = 0.9

#計算する固有周波数の数
num_bands = 6

#メッシュの細かさ
resolution = 32

#計算間隔
interpolate = 4

#-------------------------------------------------------------------#


#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1, 10*h),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

tri1 = [mp.Vector3(1,1,0)*s_param,
       mp.Vector3(-1,0,0)*s_param,
       mp.Vector3(0,-1,0)*s_param
      ]

#構造
s_param = s/(np.sqrt(3))
# ▷
tri1 = [
        mp.Vector3(-1,-1)*s_param,
        mp.Vector3(1,0)*s_param,
        mp.Vector3(0,1)*s_param
      ]

# ◁
tri2 = [
        mp.Vector3(1,1)*s_param,
        mp.Vector3(-1,0)*s_param,
        mp.Vector3(0,-1)*s_param
      ]

geometry = [
            mp.Block(material=mp.Medium(epsilon=1),
                        size=mp.Vector3(mp.inf, mp.inf, 10*h)),
            mp.Block(material=mp.Medium(epsilon=n_si**2),
                        size=mp.Vector3(mp.inf, mp.inf, h)),

            mp.Prism(tri1, center=mp.Vector3(1/3, 1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),
            
            mp.Prism(tri2, center=mp.Vector3(1/3, 0)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri1, center=mp.Vector3(0, -1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri2, center=mp.Vector3(-1/3, -1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Prism(tri1, center=mp.Vector3(-1/3, 0)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2)),
    
            mp.Prism(tri2, center=mp.Vector3(0, 1/3)*r, height=h,
                        material=mp.Medium(epsilon=n_air**2))
]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(interpolate, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

#ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
#                               mpb.fix_efield_phase,
#                               mpb.output_efield_z))
#tm_freqs = ms.all_freqs
#tm_gaps = ms.gap_list
hfields = []
ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,get_hfields))

te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 32 x 32 x 160.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 5)
# Cell volume = 4.33013
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.3,0.3,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.126795,0.126795,-0.25)
#           (0.473205,0.3,-0.25)
#           (0.3,0.473205,-0.25)
#      prism, center = (0.3,0,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.473205,0.173205,-0.25)
#           (0.126795,0,-0.25)
#           (0.3,-0.173205,-0.25)
#      prism, center = (0,-0.3,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.473205,-0.25)
#           (0.173205,-0.3,-0.25)
#           (0,-0.126795,-0.25)
#      prism, center = (-0.3,-0.3,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.126795,-0.126795,-0.25)
#           (-0.473205,-0.3,-0.25)
#           (-0.3,-0.473205,-0.25)
#      prism, center = (-0.3,0,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.473205,-0.173205,-0.25)
#           (-0.126795,0,-0.25)
#           (-0.3,0.173205,-0.25)
#      prism, center = (0,0.3,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.473205,-0.25)
#           (-0.173205,0.3,-0.25)
#           (0,0.126795,-0.25)
# Geometric object tree has depth 7 and 341 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.4718360900878906
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 49 iterations.
# zevenfreqs:, 1, 0, 0, 0, 0, 0, 0.144544, 0.145329, 0.335479, 0.335934, 0.444026
# elapsed time for k point: 18.542261838912964
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 0.480562
# Fixing h-field (band 2) phase by -0.897493 + -0.441029i; max ampl. = 0.637808
# Fixing h-field (band 3) phase by 0.617371 + 0.786672i; max ampl. = 0.637558
# Fixing h-field (band 4) phase by -0.391976 + 0.919975i; max ampl. = 0.775913
# Fixing h-field (band 5) phase by 0.106691 + -0.994292i; max ampl. = 0.807315
# Fixing h-field (band 6) phase by -0.710267 + 0.703932i; max ampl. = 2.73211
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 22 iterations.
# zevenfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0847255, 0.176252, 0.183478, 0.352971, 0.353341, 0.427237
# elapsed time for k point: 9.611103773117065
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 15 iterations.
# zevenfreqs:, 3, 0.2, 0, 0, 0.23094, 0.146132, 0.259401, 0.267415, 0.393134, 0.399504, 0.404724
# elapsed time for k point: 6.669959545135498
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 58 iterations.
# zevenfreqs:, 4, 0.3, 0, 0, 0.34641, 0.194337, 0.358973, 0.36456, 0.364777, 0.404059, 0.468806
# elapsed time for k point: 27.58503484725952
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 31 iterations.
# zevenfreqs:, 5, 0.4, 0, 0, 0.46188, 0.237558, 0.322329, 0.395042, 0.464263, 0.4703, 0.474591
# elapsed time for k point: 14.625133991241455
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 49 iterations.
# zevenfreqs:, 6, 0.5, 0, 0, 0.57735, 0.269193, 0.292468, 0.392465, 0.469837, 0.544721, 0.551933
# elapsed time for k point: 27.564162731170654
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# zevenfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.270566, 0.293619, 0.386499, 0.475547, 0.546942, 0.55434
# elapsed time for k point: 8.363121509552002
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 15 iterations.
# zevenfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.274585, 0.297035, 0.372074, 0.489198, 0.552872, 0.561228
# elapsed time for k point: 7.261882781982422
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 39 iterations.
# zevenfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.28092, 0.302593, 0.353802, 0.506178, 0.557454, 0.571506
# elapsed time for k point: 17.753061771392822
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 32 iterations.
# zevenfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.288758, 0.310101, 0.334337, 0.523938, 0.551413, 0.568713
# elapsed time for k point: 18.281795978546143
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# zevenfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.294125, 0.317673, 0.319817, 0.538637, 0.542978, 0.563636
# elapsed time for k point: 8.040621995925903
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 49 iterations.
# zevenfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.26347, 0.332043, 0.341315, 0.51343, 0.525537, 0.534667
# elapsed time for k point: 26.57549238204956
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 25 iterations.
# zevenfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.215548, 0.361991, 0.368693, 0.411806, 0.414904, 0.498138
# elapsed time for k point: 14.764995336532593
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 16 iterations.
# zevenfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.162292, 0.29062, 0.296801, 0.393501, 0.398236, 0.421086
# elapsed time for k point: 10.538728475570679
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 85 iterations.
# zevenfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0960142, 0.186524, 0.194507, 0.358606, 0.358951, 0.425365
# elapsed time for k point: 48.643982887268066
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 17 iterations.
# zevenfreqs:, 16, 0, 0, 0, 0, 0, 0.144544, 0.145329, 0.335479, 0.335934, 0.444026
# elapsed time for k point: 10.12739896774292
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 0.480562
# Fixing h-field (band 2) phase by -0.0167426 + 0.99986i; max ampl. = 0.637806
# Fixing h-field (band 3) phase by 0.0171423 + -0.999853i; max ampl. = 0.637557
# Fixing h-field (band 4) phase by -0.0186946 + 0.999825i; max ampl. = 0.775965
# Fixing h-field (band 5) phase by -0.0171339 + 0.999853i; max ampl. = 0.807309
# Fixing h-field (band 6) phase by 0.0666272 + -0.997778i; max ampl. = 2.73367
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2941247389436551 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.14454377304234717 at Vector3<0.0, 0.0, 0.0> to 0.3619907116522697 at Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
# Band 3 range: 0.14532878633008167 at Vector3<0.0, 0.0, 0.0> to 0.39504167122677536 at Vector3<0.4, 0.0, 0.0>
# Band 4 range: 0.3354792816514078 at Vector3<0.0, 0.0, 0.0> to 0.5386373569217413 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.3359344941236954 at Vector3<0.0, 0.0, 0.0> to 0.5574540921728423 at Vector3<0.39999999999999997, 0.2, 0.0>
# Band 6 range: 0.40472417568031993 at Vector3<0.2, 0.0, 0.0> to 0.5715055430588037 at Vector3<0.39999999999999997, 0.2, 0.0>
# total elapsed time for run: 276.09761333465576
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.imshow(converted_eps[:,:,400].T, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-12.1104, mean 1.81389, harm. mean 1.08322, 8.98254% > 1, 7.32546% "fill"

# %%
def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

#ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

plt.figure(figsize=(15,10))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps[:,:,400].T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ba6c4bd9bf73> in <module>
#      16
#      17 for i, f in enumerate(converted):
# ---> 18     plt.subplot(331 + i)
#      19     plt.contour(converted_eps[:,:,400].T, cmap='binary')
#      20     plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 12, not 0

# %%
#THz表示
a = 820
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
