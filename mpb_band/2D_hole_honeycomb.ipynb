# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 2.6
r = 0.14


#計算する固有周波数の数
num_bands = 6

#メッシュの細かさ
resolution = 32

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))

#構造
#default_material = mp.Medium(epsilon=n_si**2)
geometry = [
            mp.Block(material=mp.Medium(epsilon=n_si**2),
                        size=mp.Vector3(mp.inf, mp.inf)),
            mp.Cylinder(r, center=mp.Vector3(1 / 6, 1 / 6), height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),
            mp.Cylinder(r, center=mp.Vector3(1 / -6, 1 / -6), height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2))
           ]


#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(y=0.5),          # M
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03260993957519531
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 11 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653, 0.456851, 0.474892
# elapsed time for k point: 0.07747983932495117
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.047364, 0.415764, 0.431592, 0.45568, 0.477211, 0.49979
# elapsed time for k point: 0.034198760986328125
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0946643, 0.373002, 0.41489, 0.444225, 0.504009, 0.533963
# elapsed time for k point: 0.03535318374633789
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.141818, 0.328333, 0.402448, 0.433328, 0.533325, 0.56736
# elapsed time for k point: 0.03139209747314453
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.188631, 0.282809, 0.394779, 0.426077, 0.564632, 0.599667
# elapsed time for k point: 0.02473282814025879
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 33 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.229097, 0.242744, 0.392188, 0.423563, 0.594834, 0.600754
# elapsed time for k point: 0.08865618705749512
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.230584, 0.244331, 0.377142, 0.438462, 0.587543, 0.596321
# elapsed time for k point: 0.03898024559020996
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.234964, 0.249026, 0.352678, 0.46247, 0.574486, 0.585951
# elapsed time for k point: 0.03772926330566406
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.241987, 0.256645, 0.326964, 0.487344, 0.560974, 0.573343
# elapsed time for k point: 0.027695417404174805
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.251032, 0.266911, 0.301317, 0.511299, 0.54885, 0.56021
# elapsed time for k point: 0.03460335731506348
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.258292, 0.279473, 0.279505, 0.525309, 0.547202, 0.547306
# elapsed time for k point: 0.027138233184814453
# Fixing e-field (band 1) phase by -1 + 8.26966e-07i; max ampl. = 0.72658
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by -1 + 8.26966e-07i; max ampl. = 0.648859
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by 1 + -8.26966e-07i; max ampl. = 0.749196
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 1 + -8.26966e-07i; max ampl. = 0.755854
# Outputting fields to e.k11.b04.z.tm.h5...
# Fixing e-field (band 5) phase by -8.26966e-07 + -1i; max ampl. = 0.68677
# Outputting fields to e.k11.b05.z.tm.h5...
# Fixing e-field (band 6) phase by 1 + -8.26966e-07i; max ampl. = 0.717598
# Outputting fields to e.k11.b06.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.217259, 0.296568, 0.310212, 0.50767, 0.523248, 0.591479
# elapsed time for k point: 0.02623724937438965
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 13 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.163615, 0.331547, 0.346125, 0.488776, 0.502851, 0.598588
# elapsed time for k point: 0.049016475677490234
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.109274, 0.370879, 0.38452, 0.474418, 0.486318, 0.552369
# elapsed time for k point: 0.03528547286987305
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0546873, 0.412623, 0.421839, 0.46522, 0.472025, 0.506843
# elapsed time for k point: 0.05720996856689453
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 7 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653, 0.456851, 0.474892
# elapsed time for k point: 0.03291034698486328
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2582915167894548 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.24274408089640775 at Vector3<0.0, 0.5, 0.0> to 0.44860809967578213 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.27950521290855995 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4486522205584061 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.42356311420027587 at Vector3<0.0, 0.5, 0.0> to 0.5253094083120731 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.4568509434650336 at Vector3<0.0, 0.0, 0.0> to 0.5948341748880289 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 0.4748920210437326 at Vector3<0.0, 0.0, 0.0> to 0.6007543801215993 at Vector3<0.0, 0.5, 0.0>
# total elapsed time for run: 0.7497193813323975
# done
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.02443385124206543
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 13 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.449103, 0.457009, 0.482864, 0.482962, 0.546193
# elapsed time for k point: 0.06712985038757324
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 72 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.0493878, 0.427458, 0.443635, 0.478998, 0.501244, 0.55309
# elapsed time for k point: 0.15055370330810547
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.0986961, 0.387705, 0.423599, 0.470976, 0.531535, 0.570126
# elapsed time for k point: 0.035811424255371094
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.147804, 0.342544, 0.408104, 0.463384, 0.564395, 0.592674
# elapsed time for k point: 0.03416037559509277
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.196353, 0.295741, 0.398467, 0.4583, 0.596643, 0.618517
# elapsed time for k point: 0.056438446044921875
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 21 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.23572, 0.256883, 0.395197, 0.456532, 0.615442, 0.645651
# elapsed time for k point: 0.08318018913269043
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 87 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.23755, 0.25822, 0.384716, 0.466714, 0.608105, 0.641095
# elapsed time for k point: 0.16944599151611328
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.242953, 0.262168, 0.362907, 0.487566, 0.594421, 0.629257
# elapsed time for k point: 0.03752708435058594
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.251689, 0.268513, 0.337795, 0.510844, 0.579773, 0.617254
# elapsed time for k point: 0.032155513763427734
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.263409, 0.276581, 0.312024, 0.533448, 0.565338, 0.607054
# elapsed time for k point: 0.03169751167297363
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.277697, 0.277735, 0.294667, 0.551512, 0.551544, 0.602114
# elapsed time for k point: 0.03213334083557129
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 11 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.226568, 0.312422, 0.317744, 0.526542, 0.55387, 0.626622
# elapsed time for k point: 0.03872847557067871
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.170553, 0.350406, 0.352747, 0.505998, 0.53823, 0.624619
# elapsed time for k point: 0.04320096969604492
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.113926, 0.38672, 0.395809, 0.490893, 0.521799, 0.585934
# elapsed time for k point: 0.03307175636291504
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0570226, 0.423911, 0.436664, 0.482616, 0.502032, 0.556395
# elapsed time for k point: 0.03090214729309082
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 9 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.449103, 0.457009, 0.482864, 0.482962, 0.546188
# elapsed time for k point: 0.037264108657836914
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2776965052661933 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2568827703814708 at Vector3<0.0, 0.5, 0.0> to 0.4491034724129394 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.29466737928492254 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.4570093380559159 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4565324579505837 at Vector3<0.0, 0.5, 0.0> to 0.5515116341457446 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.48296182000672844 at Vector3<0.0, 0.0, 0.0> to 0.6154423149661075 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 0.5461875682216437 at Vector3<0.0, 0.0, 0.0> to 0.6456513699838858 at Vector3<0.0, 0.5, 0.0>
# total elapsed time for run: 0.9432594776153564
# done

# %%
md = mpb.MPBData(rectify=True, periods=5, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-6.76, mean 5.94096, harm. mean 3.92455, 89.8438% > 1, 85.7805% "fill"
# (320, 277)

# %%
import csv
with open(out_dir / 'epsilon_distribution.csv', 'wt') as f:
    writer = csv.writer(f)
    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()

# %%
tm_freqs.max()
# Out:
# 0.6007543801215993

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03852105140686035
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 11 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653, 0.456851, 0.474892
# elapsed time for k point: 0.10100984573364258
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.047364, 0.415764, 0.431592, 0.45568, 0.477211, 0.49979
# elapsed time for k point: 0.03717660903930664
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0946643, 0.373002, 0.41489, 0.444225, 0.504009, 0.533963
# elapsed time for k point: 0.044063568115234375
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.141818, 0.328333, 0.402448, 0.433328, 0.533325, 0.56736
# elapsed time for k point: 0.036295175552368164
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.188631, 0.282809, 0.394779, 0.426077, 0.564632, 0.599667
# elapsed time for k point: 0.037111759185791016
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 60 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.229097, 0.242744, 0.392188, 0.423563, 0.594834, 0.600754
# elapsed time for k point: 0.14738059043884277
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.230584, 0.244331, 0.377142, 0.438462, 0.587543, 0.596321
# elapsed time for k point: 0.05026960372924805
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.234964, 0.249026, 0.352678, 0.46247, 0.574486, 0.585951
# elapsed time for k point: 0.047614097595214844
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.241987, 0.256645, 0.326964, 0.487344, 0.560974, 0.573343
# elapsed time for k point: 0.04712629318237305
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.251032, 0.266911, 0.301317, 0.511299, 0.54885, 0.56021
# elapsed time for k point: 0.03671979904174805
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.258292, 0.279473, 0.279505, 0.525309, 0.547202, 0.547306
# elapsed time for k point: 0.03095841407775879
# Fixing e-field (band 1) phase by 1 + -6.11462e-07i; max ampl. = 0.72658
# Fixing e-field (band 2) phase by -1 + 6.11462e-07i; max ampl. = 0.648859
# Fixing e-field (band 3) phase by 1 + -6.11462e-07i; max ampl. = 0.749196
# Fixing e-field (band 4) phase by -1 + 6.11462e-07i; max ampl. = 0.755854
# Fixing e-field (band 5) phase by 6.11462e-07 + 1i; max ampl. = 0.68677
# Fixing e-field (band 6) phase by -1 + 6.11462e-07i; max ampl. = 0.717598
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.217259, 0.296568, 0.310212, 0.50767, 0.523248, 0.591479
# elapsed time for k point: 0.03972935676574707
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 13 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.163615, 0.331547, 0.346125, 0.488776, 0.502851, 0.598588
# elapsed time for k point: 0.06486368179321289
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.109274, 0.370879, 0.38452, 0.474418, 0.486318, 0.552369
# elapsed time for k point: 0.038649797439575195
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0546873, 0.412623, 0.421839, 0.46522, 0.472025, 0.506843
# elapsed time for k point: 0.0329437255859375
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 7 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653, 0.456851, 0.474892
# elapsed time for k point: 0.03405570983886719
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2582915167894632 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2427441918842381 at Vector3<0.0, 0.5, 0.0> to 0.44860809693441517 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.27950521290856384 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.44865221973967995 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.42356326361567176 at Vector3<0.0, 0.5, 0.0> to 0.5253094083120853 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.4568509434683473 at Vector3<0.0, 0.0, 0.0> to 0.5948342264783646 at Vector3<0.0, 0.5, 0.0>
# Band 6 range: 0.4748920211904834 at Vector3<0.0, 0.0, 0.0> to 0.6007543836879776 at Vector3<0.0, 0.5, 0.0>
# total elapsed time for run: 0.8796555995941162
# done

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
