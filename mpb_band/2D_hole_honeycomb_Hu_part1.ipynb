# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 2.6
r = 1/10

r = 1.1

#計算する固有周波数の数
num_bands = 6

#メッシュの細かさ
resolution = 64

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

#構造
#default_material = mp.Medium(epsilon=n_si**2)
geometry = [
            mp.Block(material=mp.Medium(epsilon=n_si**2),
                        size=mp.Vector3(mp.inf, mp.inf)),

            mp.Cylinder(r, center=mp.Vector3(1 / 3, 1 / 3)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),
            
            mp.Cylinder(r, center=mp.Vector3(1 / 3, 0)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Cylinder(r, center=mp.Vector3(0, -1 /3)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Cylinder(r, center=mp.Vector3(-1 / 3, -1 / 3)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),

            mp.Cylinder(r, center=mp.Vector3(-1 / 3, 0)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2)),
    
            mp.Cylinder(r, center=mp.Vector3(0, 1 /3)*r, height=mp.inf,
                        material=mp.Medium(epsilon=n_air**2))
    
           ]


#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.366667,0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.366667,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.366667,-0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.366667,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 33 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.054582834243774414
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 14 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.45253, 0.453255, 0.490051, 0.490073, 0.524744
# elapsed time for k point: 0.1457531452178955
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 15 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0492007, 0.429944, 0.442856, 0.479331, 0.501702, 0.538863
# elapsed time for k point: 0.11693716049194336
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.23094, 0.098354, 0.387486, 0.427797, 0.46342, 0.526322, 0.564885
# elapsed time for k point: 0.06797599792480469
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.34641, 0.147406, 0.341093, 0.415727, 0.45061, 0.55521, 0.594354
# elapsed time for k point: 0.07371687889099121
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.46188, 0.196274, 0.293444, 0.408126, 0.442528, 0.585882, 0.624818
# elapsed time for k point: 0.07085037231445312
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.57735, 0.242095, 0.247989, 0.405538, 0.439775, 0.608615, 0.646363
# elapsed time for k point: 0.08823418617248535
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 82 iterations.
# tmfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.243682, 0.24962, 0.390293, 0.45479, 0.602393, 0.629995
# elapsed time for k point: 0.46532702445983887
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.248376, 0.254447, 0.36498, 0.479369, 0.589796, 0.617609
# elapsed time for k point: 0.11331653594970703
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.255974, 0.262286, 0.338108, 0.504812, 0.575852, 0.604145
# elapsed time for k point: 0.07534933090209961
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.266106, 0.27286, 0.310843, 0.52929, 0.561977, 0.591856
# elapsed time for k point: 0.06455421447753906
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.276061, 0.285843, 0.285845, 0.548656, 0.54868, 0.585129
# elapsed time for k point: 0.05784034729003906
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.226363, 0.310739, 0.31767, 0.524635, 0.543335, 0.617692
# elapsed time for k point: 0.054383039474487305
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 77 iterations.
# tmfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.170117, 0.347405, 0.355133, 0.505012, 0.524538, 0.632876
# elapsed time for k point: 0.42679619789123535
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.113544, 0.387449, 0.395617, 0.490924, 0.509224, 0.587616
# elapsed time for k point: 0.05926060676574707
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0568091, 0.427544, 0.434385, 0.484703, 0.49808, 0.545988
# elapsed time for k point: 0.05324840545654297
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 9 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.45253, 0.453255, 0.490051, 0.490073, 0.524742
# elapsed time for k point: 0.0699307918548584
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27606053932193064 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.24798852501242818 at Vector3<0.5, 0.0, 0.0> to 0.45253032826470835 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.28584480965321385 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.45325457866061813 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.43977548884047163 at Vector3<0.5, 0.0, 0.0> to 0.5486559428827471 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.4900727807687628 at Vector3<0.0, 0.0, 0.0> to 0.6086149061371232 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5247419941626654 at Vector3<0.0, 0.0, 0.0> to 0.6463627387780623 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 2.062014102935791
# done
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.366667,0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.366667,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.366667,-0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.366667,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0.366667,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 33 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0545046329498291
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 17 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.488909, 0.488991, 0.517349, 0.527301, 0.527378
# elapsed time for k point: 0.15285205841064453
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.0523643, 0.461099, 0.475407, 0.502418, 0.544894, 0.557855
# elapsed time for k point: 0.07844734191894531
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.104673, 0.413787, 0.455859, 0.491506, 0.576388, 0.584802
# elapsed time for k point: 0.0797278881072998
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.156853, 0.363792, 0.440206, 0.482468, 0.610755, 0.612016
# elapsed time for k point: 0.07006573677062988
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.208745, 0.312979, 0.430323, 0.476615, 0.638366, 0.64975
# elapsed time for k point: 0.07154130935668945
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 88 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.254476, 0.267581, 0.426953, 0.474603, 0.66255, 0.67418
# elapsed time for k point: 0.5057582855224609
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.256266, 0.269187, 0.413128, 0.488082, 0.652707, 0.666819
# elapsed time for k point: 0.09597158432006836
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.26156, 0.273932, 0.387638, 0.512425, 0.637388, 0.653822
# elapsed time for k point: 0.0972599983215332
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.270143, 0.281588, 0.359731, 0.537887, 0.622684, 0.640129
# elapsed time for k point: 0.07561492919921875
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.281697, 0.291574, 0.331396, 0.56049, 0.611679, 0.626678
# elapsed time for k point: 0.07161927223205566
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.295845, 0.295879, 0.310792, 0.570558, 0.613775, 0.613866
# elapsed time for k point: 0.055333852767944336
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.240714, 0.330453, 0.338761, 0.553711, 0.590515, 0.656678
# elapsed time for k point: 0.0687859058380127
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 80 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.180996, 0.371066, 0.377002, 0.532648, 0.571025, 0.663538
# elapsed time for k point: 0.49987244606018066
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.120828, 0.4152, 0.419469, 0.516393, 0.555578, 0.615852
# elapsed time for k point: 0.06475210189819336
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0604577, 0.459656, 0.463229, 0.50743, 0.541923, 0.567558
# elapsed time for k point: 0.08132004737854004
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 10 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.488909, 0.488991, 0.517349, 0.527301, 0.527378
# elapsed time for k point: 0.0731663703918457
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2958449338192091 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2675812613545849 at Vector3<0.5, 0.0, 0.0> to 0.48890876603382666 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3107921438889384 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.4889912328025169 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.47460304807932674 at Vector3<0.5, 0.0, 0.0> to 0.570557952022762 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5273007091339633 at Vector3<0.0, 0.0, 0.0> to 0.6625502912346871 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5273776468765294 at Vector3<0.0, 0.0, 0.0> to 0.674180044365908 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 2.199484348297119
# done

# %%
md = mpb.MPBData(rectify=True, periods=5, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-6.76, mean 5.5063, harm. mean 3.15316, 82.5195% > 1, 78.2344% "fill"
# (320, 277)

# %%
#import csv
#with open(out_dir / 'epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()

# %%
tm_freqs.max()
# Out:
# 0.6463627387780623

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,-0.333333,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.333333,-0.333333,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.333333,0,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0,0.333333,0)
#           radius 0.1, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 33 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.06496763229370117
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 11 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.451476, 0.451481, 0.507669, 0.50769, 0.507716
# elapsed time for k point: 0.11072111129760742
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 18 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0492016, 0.430503, 0.441108, 0.485254, 0.505857, 0.533522
# elapsed time for k point: 0.11745333671569824
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.23094, 0.0983616, 0.387933, 0.42639, 0.466897, 0.528172, 0.562073
# elapsed time for k point: 0.05592489242553711
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 4 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.34641, 0.147435, 0.341307, 0.414509, 0.453244, 0.556721, 0.592664
# elapsed time for k point: 0.04954361915588379
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.46188, 0.196367, 0.293478, 0.407, 0.444818, 0.588274, 0.624613
# elapsed time for k point: 0.06708359718322754
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.57735, 0.245085, 0.245089, 0.40444, 0.441968, 0.621854, 0.6572
# elapsed time for k point: 0.06799530982971191
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.246699, 0.246702, 0.38977, 0.456497, 0.615269, 0.663996
# elapsed time for k point: 0.05763983726501465
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 78 iterations.
# tmfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.251475, 0.251478, 0.364662, 0.481183, 0.602235, 0.602247
# elapsed time for k point: 0.4869239330291748
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.259229, 0.259233, 0.337774, 0.507359, 0.587965, 0.587976
# elapsed time for k point: 0.05431628227233887
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.269692, 0.269695, 0.310302, 0.533819, 0.573814, 0.573824
# elapsed time for k point: 0.05840444564819336
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.282541, 0.282541, 0.282547, 0.56024, 0.560258, 0.560258
# elapsed time for k point: 0.06305146217346191
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.226545, 0.314053, 0.314058, 0.535757, 0.535772, 0.612554
# elapsed time for k point: 0.05776357650756836
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.170166, 0.351188, 0.351193, 0.515776, 0.51579, 0.663602
# elapsed time for k point: 0.0553128719329834
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 76 iterations.
# tmfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.113556, 0.39144, 0.391446, 0.501433, 0.501447, 0.590866
# elapsed time for k point: 0.40348124504089355
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0568105, 0.43059, 0.430597, 0.495091, 0.495103, 0.545424
# elapsed time for k point: 0.06861186027526855
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 6 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.451476, 0.451481, 0.507667, 0.507697, 0.507724
# elapsed time for k point: 0.057622671127319336
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2825407073751362 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.24508864395211774 at Vector3<0.5, 0.0, 0.0> to 0.451475575077208 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.2825468134655574 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.45148119712107454 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4419676995148346 at Vector3<0.5, 0.0, 0.0> to 0.5602398224290647 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.49510295315224734 at Vector3<0.06666666666666665, 0.06666666666666665, 0.0> to 0.6218540462931026 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5077163177397869 at Vector3<0.0, 0.0, 0.0> to 0.6639961852967219 at Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
# total elapsed time for run: 1.9012565612792969
# done

# %%
#THz表示
a = 820
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
