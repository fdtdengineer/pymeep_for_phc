# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
num_bands = 8
resolution = 32
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(y=0.5),          # M
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)
ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3), mpb.fix_efield_phase,
          mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03281402587890625
# elapsed time for k point: 0.060276031494140625
# elapsed time for k point: 0.029212474822998047
# elapsed time for k point: 0.02941298484802246
# elapsed time for k point: 0.02672123908996582
# elapsed time for k point: 0.02693486213684082
# elapsed time for k point: 0.0379025936126709
# elapsed time for k point: 0.028194665908813477
# elapsed time for k point: 0.024389266967773438
# elapsed time for k point: 0.020559310913085938
# elapsed time for k point: 0.022559165954589844
# elapsed time for k point: 0.030649423599243164
# Outputting fields to e.k11.b01.z.tm.h5...
# Outputting fields to e.k11.b02.z.tm.h5...
# Outputting fields to e.k11.b03.z.tm.h5...
# Outputting fields to e.k11.b04.z.tm.h5...
# Outputting fields to e.k11.b05.z.tm.h5...
# Outputting fields to e.k11.b06.z.tm.h5...
# Outputting fields to e.k11.b07.z.tm.h5...
# Outputting fields to e.k11.b08.z.tm.h5...
# elapsed time for k point: 0.022570371627807617
# elapsed time for k point: 0.025217771530151367
# elapsed time for k point: 0.02740478515625
# elapsed time for k point: 0.03308439254760742
# elapsed time for k point: 0.029401063919067383
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022601674803 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.44533108107085406 at Vector3<0.0, 0.5, 0.0> to 0.5605181432101889 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689674 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607971102675 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960879571479 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678292 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965161 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511186954249 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534061818 at Vector3<0.0, 0.0, 0.0> to 0.8672009266363946 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349976047847 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.994129109751552 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210413 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.09831836663255 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022601674803) to band 2 (0.44533108107085406), 47.398834832909984%
# Gap from band 3 (0.5605607971102675) to band 4 (0.5932960879571479), 5.674064309104994%
# Gap from band 4 (0.7907195975678292) to band 5 (0.7908320764965161), 0.014223870206893524%
# Gap from band 5 (0.8374511186954249) to band 6 (0.8375948534061818), 0.01716188249765666%
# Gap from band 6 (0.8672009266363946) to band 7 (0.8691349976047847), 0.2227761277513614%
# total elapsed time for run: 0.6015036106109619
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.021893024444580078
# elapsed time for k point: 0.10308218002319336
# elapsed time for k point: 0.04320931434631348
# elapsed time for k point: 0.04506850242614746
# elapsed time for k point: 0.04027676582336426
# elapsed time for k point: 0.03230094909667969
# elapsed time for k point: 0.02924180030822754
# elapsed time for k point: 0.03622603416442871
# elapsed time for k point: 0.038546085357666016
# elapsed time for k point: 0.03868412971496582
# elapsed time for k point: 0.03408074378967285
# elapsed time for k point: 0.03427433967590332
# elapsed time for k point: 0.05155539512634277
# elapsed time for k point: 0.03685402870178223
# elapsed time for k point: 0.04780387878417969
# elapsed time for k point: 0.049576759338378906
# elapsed time for k point: 0.05479168891906738
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4912358164155418 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4730722398038153 at Vector3<0.0, 0.5, 0.0> to 0.5631059454934056 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.5631505237340388 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.7939289543994171 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.767661480237272 at Vector3<0.0, 0.5, 0.0> to 0.8214230165371808 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.8651948161669996 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.033413025811256 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8652308007806795 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.033423117360895 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 1.021367720108612 at Vector3<0.0, 0.5, 0.0> to 1.1159672190021013 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 1.1086627112265817 at Vector3<-0.26666666666666666, 0.26666666666666666, 0.0> to 1.11681083983656 at Vector3<0.0, 0.0, 0.0>
# Gap from band 2 (0.5631059454934056) to band 3 (0.5631505237340388), 0.007916179280865895%
# Gap from band 4 (0.8214230165371808) to band 5 (0.8651948161669996), 5.190482251647821%
# total elapsed time for run: 0.7433562278747559
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# (96, 83)

# %%
import csv
with open(out_dir / '2D.csv', 'wt') as f:
    writer = csv.writer(f)
    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))
# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 1])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.015537500381469727
# elapsed time for k point: 0.04258012771606445
# elapsed time for k point: 0.029106855392456055
# elapsed time for k point: 0.02542877197265625
# elapsed time for k point: 0.024816274642944336
# elapsed time for k point: 0.02205061912536621
# elapsed time for k point: 0.02233433723449707
# elapsed time for k point: 0.02459263801574707
# elapsed time for k point: 0.02256941795349121
# elapsed time for k point: 0.019434213638305664
# elapsed time for k point: 0.019364356994628906
# elapsed time for k point: 0.01994037628173828
# elapsed time for k point: 0.020980119705200195
# elapsed time for k point: 0.023449420928955078
# elapsed time for k point: 0.025244474411010742
# elapsed time for k point: 0.030620098114013672
# elapsed time for k point: 0.026853084564208984
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022601674836 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.44533108106909725 at Vector3<0.0, 0.5, 0.0> to 0.560518143385505 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689683 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607973092215 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.593296087564265 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678298 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965172 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511192359284 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534061811 at Vector3<0.0, 0.0, 0.0> to 0.8672009266355641 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349976047849 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291111082572 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210428 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183592445864 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022601674836) to band 2 (0.44533108106909725), 47.398834832537524%
# Gap from band 3 (0.5605607973092215) to band 4 (0.593296087564265), 5.674064207474524%
# Gap from band 4 (0.7907195975678298) to band 5 (0.7908320764965172), 0.014223870206949667%
# Gap from band 5 (0.8374511192359284) to band 6 (0.8375948534061811), 0.017161817956075593%
# Gap from band 6 (0.8672009266355641) to band 7 (0.8691349976047849), 0.2227761278471358%
# total elapsed time for run: 0.42571520805358887
# done
