# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %% [markdown]
# 参考
# https://mpb.readthedocs.io/en/latest/Python_Data_Analysis_Tutorial/

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 2.7

#三角形の一辺
s = 0.8
s_param = s/np.sqrt(3)

#計算する固有周波数の数
num_bands = 4

#メッシュの細かさ
resolution = 32

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

#三角形
tri_before_modified = [
        mp.Vector3(2,0)*s_param,
        mp.Vector3(-1,np.sqrt(3))*s_param,
        mp.Vector3(-1,-np.sqrt(3))*s_param
      ]

tri1 = [
        mp.Vector3(1,1)*s_param,
        mp.Vector3(-1,0)*s_param,
        mp.Vector3(0,-1)*s_param
      ]


#構造
geometry = [
    mp.Block(material=mp.Medium(epsilon=n_si**2),
             size=mp.Vector3(mp.inf, mp.inf)),
    mp.Prism(tri1, center=mp.Vector3(), height=50,
            material=mp.Medium(epsilon=n_air**2)),
]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te(mpb.output_at_kpoint(mp.Vector3(1./3, 1./3),
                               mpb.fix_hfield_phase,
                               mpb.output_hfield_z))
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 50, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.490748,0.490748,-25)
#           (-0.490748,0,-25)
#           (0,-0.490748,-25)
# Geometric object tree has depth 3 and 45 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03956913948059082
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 13 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.433276, 0.456901, 0.456955
# elapsed time for k point: 0.027104616165161133
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0514838, 0.412508, 0.452211, 0.471876
# elapsed time for k point: 0.022783756256103516
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.23094, 0.102572, 0.37937, 0.441993, 0.482787
# elapsed time for k point: 0.023364543914794922
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.34641, 0.15274, 0.341594, 0.431877, 0.480214
# elapsed time for k point: 0.017771005630493164
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.46188, 0.200798, 0.30078, 0.424939, 0.474375
# elapsed time for k point: 0.020574092864990234
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.57735, 0.234338, 0.269609, 0.422503, 0.471917
# elapsed time for k point: 0.014565467834472656
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.235866, 0.270739, 0.412173, 0.482267
# elapsed time for k point: 0.015513420104980469
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.240386, 0.273744, 0.392364, 0.502336
# elapsed time for k point: 0.015326499938964844
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.247719, 0.277186, 0.372086, 0.523919
# elapsed time for k point: 0.0257413387298584
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.257599, 0.277615, 0.35627, 0.544138
# elapsed time for k point: 0.016085147857666016
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.269701, 0.269733, 0.350337, 0.559896
# elapsed time for k point: 0.011568546295166016
# Fixing e-field (band 1) phase by -0.999979 + -0.00642656i; max ampl. = 0.715138
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by -0.570108 + 0.82157i; max ampl. = 0.630991
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by -0.815433 + 0.578851i; max ampl. = 0.683233
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 0.468731 + 0.883341i; max ampl. = 0.793641
# Outputting fields to e.k11.b04.z.tm.h5...
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tmfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.229031, 0.299312, 0.366847, 0.536644
# elapsed time for k point: 0.018933534622192383
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.175495, 0.333904, 0.3977, 0.515529
# elapsed time for k point: 0.016023874282836914
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.118225, 0.371099, 0.428437, 0.496052
# elapsed time for k point: 0.016141653060913086
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0594238, 0.407989, 0.449815, 0.475465
# elapsed time for k point: 0.016695261001586914
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 8 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.433276, 0.456901, 0.456955
# elapsed time for k point: 0.014686822891235352
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.26970068940640507 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.26960926124753376 at Vector3<0.5, 0.0, 0.0> to 0.433276463436275 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.35033716069439563 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.45690063797472585 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.45695509413734686 at Vector3<0.0, 0.0, 0.0> to 0.5598955588747812 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 3 (0.45690063797472585) to band 4 (0.45695509413734686), 0.01191789047383902%
# total elapsed time for run: 0.3657546043395996
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 50, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.490748,0.490748,-25)
#           (-0.490748,0,-25)
#           (0,-0.490748,-25)
# Geometric object tree has depth 3 and 45 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.04317927360534668
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 22 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.487008, 0.56333, 0.56452
# elapsed time for k point: 0.03625988960266113
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 25 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.0589739, 0.479058, 0.549803, 0.562175
# elapsed time for k point: 0.037056684494018555
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.117313, 0.45725, 0.513191, 0.552244
# elapsed time for k point: 0.023525714874267578
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.173848, 0.420608, 0.487354, 0.54315
# elapsed time for k point: 0.02051544189453125
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.224825, 0.377276, 0.474874, 0.537051
# elapsed time for k point: 0.019666671752929688
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.251744, 0.352323, 0.471127, 0.534923
# elapsed time for k point: 0.02228522300720215
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.253943, 0.353382, 0.460772, 0.544941
# elapsed time for k point: 0.018770694732666016
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.260212, 0.356539, 0.439173, 0.565707
# elapsed time for k point: 0.017514944076538086
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.269459, 0.361715, 0.414978, 0.589231
# elapsed time for k point: 0.017818450927734375
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.279261, 0.368775, 0.392308, 0.613135
# elapsed time for k point: 0.024482250213623047
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.284246, 0.376037, 0.378135, 0.634001
# elapsed time for k point: 0.02957296371459961
# Fixing h-field (band 1) phase by 0.987086 + -0.160193i; max ampl. = 1.4243
# Outputting fields to h.k11.b01.z.te.h5...
# Fixing h-field (band 2) phase by 0.153076 + -0.988214i; max ampl. = 1.95119
# Outputting fields to h.k11.b02.z.te.h5...
# Fixing h-field (band 3) phase by -0.998794 + -0.0491074i; max ampl. = 1.99388
# Outputting fields to h.k11.b03.z.te.h5...
# Fixing h-field (band 4) phase by 0.743316 + 0.66894i; max ampl. = 2.25551
# Outputting fields to h.k11.b04.z.te.h5...
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.257311, 0.389067, 0.398531, 0.612323
# elapsed time for k point: 0.018980979919433594
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.200101, 0.425145, 0.434457, 0.593548
# elapsed time for k point: 0.017467498779296875
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.135418, 0.452921, 0.488721, 0.57875
# elapsed time for k point: 0.022867918014526367
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 17 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0681875, 0.476703, 0.542317, 0.568564
# elapsed time for k point: 0.026167631149291992
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 18 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.487008, 0.56333, 0.56452
# elapsed time for k point: 0.02686023712158203
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28424603687356137 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.3523232609629614 at Vector3<0.5, 0.0, 0.0> to 0.4870077346680443 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3781348992450646 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.563330282067967 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5349229642977337 at Vector3<0.5, 0.0, 0.0> to 0.6340014665220526 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.28424603687356137) to band 2 (0.3523232609629614), 21.38878652199244%
# total elapsed time for run: 0.47087788581848145
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.imshow(converted_eps.T, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-7.29, mean 5.01812, harm. mean 2.35102, 69.1406% > 1, 63.8811% "fill"

# %%
#import csv
#with open(out_dir / 'epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
tm_freqs.max()
# Out:
# 0.5598955588747815

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
hfields = []

def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,
          get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=64, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 50, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.490748,0.490748,-25)
#           (-0.490748,0,-25)
#           (0,-0.490748,-25)
# Geometric object tree has depth 3 and 45 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.042725563049316406
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 21 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.487008, 0.56333, 0.56452
# elapsed time for k point: 0.03519582748413086
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 0.995067 + 0.099202i; max ampl. = 2.60898
# Fixing h-field (band 3) phase by -0.659875 + 0.751375i; max ampl. = 2.83656
# Fixing h-field (band 4) phase by 0.888066 + 0.459715i; max ampl. = 2.57747
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 25 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.0589739, 0.479058, 0.549803, 0.562175
# elapsed time for k point: 0.044675350189208984
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.117313, 0.45725, 0.513191, 0.552244
# elapsed time for k point: 0.022852182388305664
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.173848, 0.420608, 0.487354, 0.54315
# elapsed time for k point: 0.023604631423950195
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.224825, 0.377276, 0.474874, 0.537051
# elapsed time for k point: 0.02287769317626953
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.251744, 0.352323, 0.471127, 0.534923
# elapsed time for k point: 0.020986557006835938
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.253943, 0.353382, 0.460772, 0.544941
# elapsed time for k point: 0.018740177154541016
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.260212, 0.356539, 0.439173, 0.565707
# elapsed time for k point: 0.022448301315307617
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.269459, 0.361715, 0.414978, 0.589231
# elapsed time for k point: 0.02039790153503418
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.279261, 0.368775, 0.392308, 0.613135
# elapsed time for k point: 0.021300554275512695
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.284246, 0.376037, 0.378135, 0.634001
# elapsed time for k point: 0.030813932418823242
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.257311, 0.389067, 0.398531, 0.612323
# elapsed time for k point: 0.02309441566467285
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.200101, 0.425145, 0.434457, 0.593548
# elapsed time for k point: 0.022179841995239258
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.135418, 0.452921, 0.488721, 0.57875
# elapsed time for k point: 0.018718242645263672
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 17 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0681875, 0.476703, 0.542317, 0.568564
# elapsed time for k point: 0.031759023666381836
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 18 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.487008, 0.56333, 0.56452
# elapsed time for k point: 0.02466440200805664
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 0.239928 + 0.970791i; max ampl. = 2.60911
# Fixing h-field (band 3) phase by -0.406596 + 0.913608i; max ampl. = 2.83686
# Fixing h-field (band 4) phase by -0.952364 + 0.304963i; max ampl. = 2.57757
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2842460368736435 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.3523232609629615 at Vector3<0.5, 0.0, 0.0> to 0.48700773909315487 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3781348992450733 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.5633302820679662 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5349229642977339 at Vector3<0.5, 0.0, 0.0> to 0.6340014665249426 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.2842460368736435) to band 2 (0.3523232609629615), 21.38878652196389%
# total elapsed time for run: 0.46561312675476074
# done

# %%
efields
# Out:
# [MPBArray([[[[ 2.15318879e-03+1.70313512e-03j,
#                9.05527333e-01+9.78473952e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.40975566e-01-2.80119280e-02j,
#                6.49822721e-01+4.14450457e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.19273390e-01-5.64944898e-02j,
#                5.97962045e-01+6.12433351e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[ 2.68362783e-02-2.42821912e-01j,
#               -2.27377460e-01+3.62769203e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.04799529e-01-2.76312578e-01j,
#               -2.42351366e-01+3.59096155e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.35374867e-01-2.53583161e-01j,
#               -4.06415040e-01+6.06617969e-01j,
#               -0.00000000e+00+0.00000000e+00j]]],
#
#
#            [[[-1.43247466e-01+2.53123129e-02j,
#                6.62066407e-01+4.34349076e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 6.08908945e-03+1.58244785e-03j,
#                6.98693287e-01+6.55514055e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 6.29449228e-02-3.32009183e-02j,
#                6.11015988e-01+5.06837334e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[-2.62544746e-02-2.34745991e-01j,
#               -2.45271830e-01+3.63627541e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 6.65848656e-03-2.18228340e-01j,
#               -2.96829272e-01+4.25945354e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 5.21924992e-02-2.01076560e-01j,
#               -3.27174137e-01+4.65262321e-01j,
#               -0.00000000e+00+0.00000000e+00j]]],
#
#
#            [[[-1.17308248e-01+5.86166865e-02j,
#                5.99259261e-01+6.05520336e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[-6.21738761e-02+3.18897423e-02j,
#                6.14232960e-01+5.11486591e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.98665064e-03+6.37600697e-04j,
#                6.16320758e-01+4.80563164e-02j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[-7.81712290e-02-2.33759986e-01j,
#               -2.67822834e-01+3.68895960e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[-2.82955871e-02-2.15265594e-01j,
#               -2.67307493e-01+3.91446219e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[-1.18671092e-02-1.86947170e-01j,
#               -3.12402291e-01+4.43320613e-01j,
#               -0.00000000e+00+0.00000000e+00j]]],
#
#
#            ...,
#
#
#            [[[-2.66943121e-02+2.44259190e-01j,
#               -2.26191331e-01+3.59948458e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 2.73799712e-02+2.32048304e-01j,
#               -2.46540484e-01+3.65078141e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 7.84249310e-02+2.33764506e-01j,
#               -2.67080480e-01+3.68501432e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[
-01j,
#                0.00000000e+00-0.00000000e+00j]],
#
#             [[-4.49732284e-03+2.42655810e-02j,
#               -1.01570174e+00+3.57959554e-01j,
#                0.00000000e+00-0.00000000e+00j]],
#
#             [[-2.55035008e-01+1.22980630e-01j,
#               -3.94292579e-01+1.30391313e-01j,
#                0.00000000e+00-0.00000000e+00j]]],
#
#
#            [[[ 2.28987704e-01+1.81319608e-01j,
#                1.93627513e-01+2.03612620e-01j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.57451633e-01+1.09370818e-01j,
#                1.50392796e-01+2.18278507e-01j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.14624161e-01+7.50829021e-02j,
#                4.33185438e-02+1.36345953e-01j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[ 1.54919635e-02-2.88755075e-02j,
#               -1.00365496e+00+3.54600752e-01j,
#                0.00000000e+00-0.00000000e+00j]],
#
#             [[-2.69547871e-02+1.24410718e-02j,
#               -1.24285489e+00+4.41543401e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[-1.70399053e-01+8.46070718e-02j,
#               -7.64083204e-01+2.31389305e-01j,
#                0.00000000e+00-0.00000000e+00j]]],
#
#
#            [[[ 1.93298221e-01+1.64198249e-01j,
#                3.30810240e-01+3.53537742e-01j,
#               -0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.41712199e-01+1.09775892e-01j,
#                1.40490053e-01+2.06832263e-01j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             [[ 1.03561081e-01+8.24355809e-02j,
#                4.75930524e-02+1.52700249e-01j,
#                0.00000000e+00+0.00000000e+00j]],
#
#             ...,
#
#             [[ 2.63474991e-01-1.23083996e-01j,
#               -3.93873017e-01+1.32044112e-01j,
#                0.00000000e+00-0.00000000e+00j]],
#
#             [[ 1.84987061e-01-9.11274974e-02j,
#               -7.17423146e-01+2.17652049e-01j,
#                0.00000000e+00-0.00000000e+00j]],
#
#             [[ 5.81803027e-02-1.66122458e-02j,
#               -9.60176473e-01+2.77702663e-01j,
#                0.00000000e+00-0.00000000e+00j]]]]),
#  MPBArray([[[[ 0.45554242+0.07821019j,  0.01963971-0.00131857j,
#                0.        +0.j        ]],
#
#             [[ 0.53692398+0.11663627j,  0.07784448+0.0511172j ,
#                0.        +0.j        ]],
#
#             [[ 0.52722412+0.12967303j,  0.04414184+0.09587856j,
#                0.        +0.j        ]],
#
#             ...,
#
#             [[-0.23247855+0.46989381j,  0.19957874-0.11950533j,
#               -0.        +0.j        ]],
#
#             [[-0.3160791 +0.48763276j,  0.1635117 -0.11878325j,
#               -0.        +0.j        ]],
#
#             [[-0.28992118+0.38593703j,  0.1285813 -0.10052587j,
#               -0.        +0.j        ]]],
#
#
#            [[[ 0.54177088+0.11250259j, -0.03690748-0.04452119j,
#                0.        +0.j        ]],
#
#             [[ 0.54242752+0.13645438j,  0.01579088+0.00229174j,
#                0.        +0.j        ]],
#
#             [[ 0.54842741+0.16977705j,  0.01419342+0.04521256j,
#                0.        +0.j        ]],
#
#             ...,
#
#             [[-0.20634314+0.41757413j,  0.24539199-0.05887628j,
#               -0.        +0.j        ]],
#
#             [[-0.26939723+0.42931187j,  0.18447393-0.04417553j,
#               -0.        +0.j        ]],
#
#             [[-0.33516396+0.43717758j,  0.1230192 -0.03159507j,
#               -0.        +0.j        ]]],
#
#
#            [[[ 0.53669047+0.11815231j, -0.01371267-0.08943773j,
#                0.        +0.j        ]],
#
#             [[ 0.55406005+0.16441754j,  0.01378283-0.03570998j,
#                0.        +0.j        ]],
#
#             [[ 0.55188343+0.18234157j,  0.01015147+0.00464419j,
#                0.        +0.j        ]],
#
#             ...,
#
#             [[-0.16274214+0.32505602j,  0.25272709+0.02711107j,
#               -0.        +0.j        ]],
#
#             [[-0.25543342+0.38199343j,  0.20031825+0.02595139j,
#               -0.        +0.j        ]],
#
#             [[-0.3223189 +0.39950732j,  0.1402471 +0.03161932j,
#               -0.        +0.j        ]]],
#
#
#            ...,
#
#
#            [[[-0.2405484 +0.45768463j, -0.21594802+0.14133061j,
#               -0.        +0.j        ]],
#
#             [[-0.21521394+0.39335381j, -0.26621391+0.08270495j,
#               -0.        +0.j        ]],
#
#             [[-0.17239933+0.29078144j, -0.2736068 -0.00690215j,
#               -0.        +0.j        ]],
#
#             ...,
#
#             [[-0.39053256-0.40285746j, -0.02683039-0.02487703j,
#                0.        -0.j        ]],
#
#             [[-0.40224551-0.50534644j, -0.07598059-0.24346771j,
#                0.        -0.j        ]],
#
#             [[-0.28426015-0.44484255j, -0.09615033-0.30118568j,
#                0.        -0.j        ]]],
#
#
#            [[[-0.32524019+0.48930807j, -0.18508162+0.15141816j,
#               -0.        +0.j        ]],
#
#             [[-0.27764061+0.41308669j, -0.20552877+0.07026393j,
#               -0.        +0.j        ]],
#
#             [[-0.26441517+0.35429436j, -0.22227312-0.00326682j,
#               -0.        +0.j        ]],
#
#             ...,
#
#             [[-0.40732585-0.50727951j,  0.02621061+0.18930525j,
#                0.        -0.j        ]],
#
#             [[-0.30805807-0.5040097j , -0.02588368-0.02733519j,
#                0.        -0.j        ]],
#
#             [[-0.24306234-0.42968046j, -0.09032239-0.2743034j ,
#                0.        -0.j        ]]],
#
#
#            [[[-0.29386312+0.38779231j, -0.15648626+0.14594419j,
#               -0.        +0.j        ]],
#
#             [[-0.34183944+0.42901107j, -0.14635503+0.06325183j,
#               -0.        +0.j        ]],
#
#             [[-0.32945278+0.37903084j, -0.16276095-0.00789958j,
#               -0.        +0.j        ]],
#
#             ...,
#
#             [[-0.28637387-0.43942159j,  0.07914528+0.2741077j ,
#                0.        -0.j        ]],
#
#             [[-0.23914646-0.41786338j,  0.0520773 +0.22122281j,
#                0.        -0.j        ]],
#
#             [[-0.23687808-0.48392192j, -0.01788278-0.0205058j ,
#                0.        -0.j        ]]]])]

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
