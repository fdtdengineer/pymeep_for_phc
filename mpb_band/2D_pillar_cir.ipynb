# %%
from pathlib import Path
import os

SCRIPT_DIR = globals().get("SCRIPT_DIR", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
FIG_DIR = SCRIPT_DIR / "fig"
OUT_DIR = SCRIPT_DIR / "out"
FIG_DIR.mkdir(exist_ok=True)
OUT_DIR.mkdir(exist_ok=True)
os.chdir(OUT_DIR)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Si = 3.48

#計算する固有周波数の数
num_bands = 8

#メッシュの細かさ
resolution = 32


#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))

#構造
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=n_Si**2))]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(y=0.5),          # M
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.023067712783813477
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 19 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.55818, 0.558222, 0.592103, 0.834219, 0.834362, 0.990407, 1.096
# elapsed time for k point: 0.1014862060546875
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0709094, 0.537048, 0.557102, 0.615532, 0.830985, 0.836199, 0.984606, 1.08458
# elapsed time for k point: 0.0536956787109375
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.13844, 0.506874, 0.554289, 0.652302, 0.82221, 0.841172, 0.965582, 1.05128
# elapsed time for k point: 0.05033683776855469
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198226, 0.478127, 0.550881, 0.691464, 0.810858, 0.847504, 0.929842, 1.02388
# elapsed time for k point: 0.04696798324584961
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.243101, 0.454393, 0.548176, 0.728474, 0.800901, 0.852811, 0.888262, 1.01159
# elapsed time for k point: 0.04848790168762207
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.260929, 0.444128, 0.547154, 0.747665, 0.796339, 0.854889, 0.867145, 1.00825
# elapsed time for k point: 0.044777631759643555
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.261891, 0.446281, 0.543625, 0.750884, 0.79553, 0.856911, 0.866797, 0.996412
# elapsed time for k point: 0.034026384353637695
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.264562, 0.452538, 0.533862, 0.759645, 0.793518, 0.862635, 0.865739, 0.970946
# elapsed time for k point: 0.038440704345703125
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.268272, 0.462311, 0.519836, 0.77164, 0.791192, 0.863907, 0.871419, 0.942371
# elapsed time for k point: 0.042568206787109375
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.271844, 0.474703, 0.503893, 0.783341, 0.789417, 0.861537, 0.882712, 0.915936
# elapsed time for k point: 0.04358029365539551
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.273523, 0.488423, 0.488676, 0.788832, 0.788938, 0.860023, 0.896206, 0.896348
# elapsed time for k point: 0.031290292739868164
# Fixing e-field (band 1) phase by -1 + -2.5543e-06i; max ampl. = 0.935263
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by 2.5543e-06 + -1i; max ampl. = 1.08095
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by -1 + -2.5543e-06i; max ampl. = 0.871827
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by -1 + -2.5543e-06i; max ampl. = 1.23795
# Outputting fields to e.k11.b04.z.tm.h5...
# Fixing e-field (band 5) phase by 2.5543e-06 + -1i; max ampl. = 1.0932
# Outputting fields to e.k11.b05.z.tm.h5...
# Fixing e-field (band 6) phase by -1 + -2.5543e-06i; max ampl. = 1.75817
# Outputting fields to e.k11.b06.z.tm.h5...
# Fixing e-field (band 7) phase by 1 + 2.5543e-06i; max ampl. = 1.07784
# Outputting fields to e.k11.b07.z.tm.h5...
# Fixing e-field (band 8) phase by 1 + 2.5543e-06i; max ampl. = 1.06806
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.262116, 0.469504, 0.516194, 0.762686, 0.793019, 0.860914, 0.894047, 0.930459
# elapsed time for k point: 0.03528785705566406
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.221759, 0.475061, 0.537818, 0.713921, 0.804137, 0.852502, 0.926882, 0.975252
# elapsed time for k point: 0.03733062744140625
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.158025, 0.499594, 0.550674, 0.665112, 0.818382, 0.843557, 0.96017, 1.02965
# elapsed time for k point: 0.04742860794067383
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0816697, 0.532576, 0.556575, 0.620926, 0.829874, 0.836863, 0.98273, 1.07983
# elapsed time for k point: 0.05113649368286133
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.55818, 0.558222, 0.592103, 0.834219, 0.834362, 0.990407, 1.096
# elapsed time for k point: 0.04146718978881836
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2735231130354919 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4441276469358828 at Vector3<0.0, 0.5, 0.0> to 0.5581802369582226 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.48867632954188284 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.558221805484122 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5921029042074527 at Vector3<0.0, 0.0, 0.0> to 0.7888318505844969 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7889383831635858 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8342188952275869 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8343624730746484 at Vector3<0.0, 0.0, 0.0> to 0.8639069213540513 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8657386674870462 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9904065700471869 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8963481590706172 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0959999957352449 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2735231130354919) to band 2 (0.4441276469358828), 47.54528063404987%
# Gap from band 3 (0.558221805484122) to band 4 (0.5921029042074527), 5.8907017188937685%
# Gap from band 4 (0.7888318505844969) to band 5 (0.7889383831635858), 0.013504194312983872%
# Gap from band 5 (0.8342188952275869) to band 6 (0.8343624730746484), 0.01720957093121888%
# Gap from band 6 (0.8639069213540513) to band 7 (0.8657386674870462), 0.21180594970582067%
# total elapsed time for run: 0.8392517566680908
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.029850482940673828
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 32 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.558892, 0.791487, 0.79221, 1.03208, 1.03209, 1.11412, 1.11495
# elapsed time for k point: 0.09900474548339844
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.101844, 0.557503, 0.789088, 0.790882, 0.991246, 1.02707, 1.09579, 1.11265
# elapsed time for k point: 0.05978727340698242
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.202608, 0.552947, 0.782222, 0.782796, 0.924058, 1.01648, 1.06775, 1.10976
# elapsed time for k point: 0.04790830612182617
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.300636, 0.543072, 0.751695, 0.774596, 0.879074, 1.0067, 1.0432, 1.10806
# elapsed time for k point: 0.05205535888671875
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.392482, 0.520172, 0.704651, 0.76824, 0.865418, 1.00052, 1.02619, 1.10725
# elapsed time for k point: 0.04205894470214844
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.468251, 0.471862, 0.68214, 0.765841, 0.863544, 0.998454, 1.02001, 1.10701
# elapsed time for k point: 0.051778316497802734
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.472475, 0.47297, 0.675019, 0.770872, 0.863444, 0.967943, 1.04889, 1.10694
# elapsed time for k point: 0.04814410209655762
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.476155, 0.484899, 0.656415, 0.782997, 0.863165, 0.930909, 1.07876, 1.10674
# elapsed time for k point: 0.04786944389343262
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.480959, 0.50482, 0.629962, 0.798036, 0.862754, 0.898149, 1.09628, 1.10644
# elapsed time for k point: 0.048470258712768555
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.486379, 0.531222, 0.597763, 0.812772, 0.862304, 0.872872, 1.10358, 1.10607
# elapsed time for k point: 0.04712963104248047
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.489674, 0.562873, 0.56292, 0.820316, 0.86197, 0.861996, 1.10553, 1.10572
# elapsed time for k point: 0.057675838470458984
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.445554, 0.530922, 0.63665, 0.80494, 0.863184, 0.890503, 1.10232, 1.10514
# elapsed time for k point: 0.053130149841308594
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.345091, 0.541032, 0.712619, 0.793018, 0.873427, 0.936524, 1.09382, 1.10575
# elapsed time for k point: 0.05731606483459473
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.23341, 0.551131, 0.767005, 0.789992, 0.911429, 0.985326, 1.08632, 1.10802
# elapsed time for k point: 0.06342577934265137
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 16 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.117531, 0.557033, 0.787415, 0.7912, 0.982211, 1.02232, 1.09411, 1.11206
# elapsed time for k point: 0.056737422943115234
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 21 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.558892, 0.791487, 0.79221, 1.03208, 1.03209, 1.11412, 1.11495
# elapsed time for k point: 0.05716657638549805
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.48967384137034353 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4718617078616752 at Vector3<0.0, 0.5, 0.0> to 0.5628729929619751 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.5629201265643996 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.7914869053924561 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.7658407972912064 at Vector3<0.0, 0.5, 0.0> to 0.8203157313826397 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.8619703714453392 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0320811823618692 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8619962161503882 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0320930983941339 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 1.0200085103323553 at Vector3<0.0, 0.5, 0.0> to 1.1141222215838036 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 1.1051409202747042 at Vector3<-0.26666666666666666, 0.26666666666666666, 0.0> to 1.1149501253072083 at Vector3<0.0, 0.0, 0.0>
# Gap from band 2 (0.5628729929619751) to band 3 (0.5629201265643996), 0.008373403888683463%
# Gap from band 4 (0.8203157313826397) to band 5 (0.8619703714453392), 4.952146961527727%
# total elapsed time for run: 0.9234263896942139
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-12.1104, mean 2.61216, harm. mean 1.1717, 17.2852% > 1, 14.5104% "fill"
# (96, 83)

# %%
import csv
with open(OUT_DIR / '2D.csv', 'wt') as f:
    writer = csv.writer(f)
    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))
# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 1])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.036339521408081055
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 16 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.55818, 0.558222, 0.592103, 0.834219, 0.834362, 0.990407, 1.096
# elapsed time for k point: 0.06466412544250488
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0709094, 0.537048, 0.557102, 0.615532, 0.830985, 0.836199, 0.984606, 1.08458
# elapsed time for k point: 0.04437446594238281
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.13844, 0.506874, 0.554289, 0.652302, 0.82221, 0.841172, 0.965582, 1.05128
# elapsed time for k point: 0.04209756851196289
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198226, 0.478127, 0.550881, 0.691464, 0.810858, 0.847504, 0.929842, 1.02388
# elapsed time for k point: 0.04837918281555176
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.243101, 0.454393, 0.548176, 0.728474, 0.800901, 0.852811, 0.888262, 1.01159
# elapsed time for k point: 0.03955888748168945
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.260929, 0.444128, 0.547154, 0.747665, 0.796339, 0.854889, 0.867145, 1.00825
# elapsed time for k point: 0.04340767860412598
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.261891, 0.446281, 0.543625, 0.750884, 0.79553, 0.856911, 0.866797, 0.996412
# elapsed time for k point: 0.043859243392944336
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.264562, 0.452538, 0.533862, 0.759645, 0.793518, 0.862635, 0.865739, 0.970946
# elapsed time for k point: 0.03895378112792969
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.268272, 0.462311, 0.519836, 0.77164, 0.791192, 0.863907, 0.871419, 0.942371
# elapsed time for k point: 0.035080671310424805
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.271844, 0.474703, 0.503893, 0.783341, 0.789417, 0.861537, 0.882712, 0.915936
# elapsed time for k point: 0.03747105598449707
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.273523, 0.488423, 0.488676, 0.788832, 0.788938, 0.860023, 0.896206, 0.896348
# elapsed time for k point: 0.03156781196594238
# Fixing e-field (band 1) phase by -1 + 3.12308e-06i; max ampl. = 0.935263
# Fixing e-field (band 2) phase by -3.12308e-06 + -1i; max ampl. = 1.08095
# Fixing e-field (band 3) phase by 1 + -3.12308e-06i; max ampl. = 0.871827
# Fixing e-field (band 4) phase by 1 + -3.12308e-06i; max ampl. = 1.23795
# Fixing e-field (band 5) phase by 3.12308e-06 + 1i; max ampl. = 1.0932
# Fixing e-field (band 6) phase by 1 + -3.12308e-06i; max ampl. = 1.75817
# Fixing e-field (band 7) phase by -1 + 3.12308e-06i; max ampl. = 1.07784
# Fixing e-field (band 8) phase by -1 + 3.12308e-06i; max ampl. = 1.06806
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.262116, 0.469504, 0.516194, 0.762686, 0.793019, 0.860914, 0.894047, 0.930459
# elapsed time for k point: 0.03810691833496094
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.221759, 0.475061, 0.537818, 0.713921, 0.804137, 0.852502, 0.926882, 0.975252
# elapsed time for k point: 0.03774285316467285
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.158025, 0.499594, 0.550674, 0.665112, 0.818382, 0.843557, 0.96017, 1.02965
# elapsed time for k point: 0.04286551475524902
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0816697, 0.532576, 0.556575, 0.620926, 0.829874, 0.836863, 0.98273, 1.07983
# elapsed time for k point: 0.05398106575012207
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.55818, 0.558222, 0.592103, 0.834219, 0.834362, 0.990407, 1.096
# elapsed time for k point: 0.04456043243408203
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27352311303547305 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4441276469358833 at Vector3<0.0, 0.5, 0.0> to 0.5581802408511599 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4886763295418784 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5582218046289625 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5921029038134862 at Vector3<0.0, 0.0, 0.0> to 0.7888318505845 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7889383831635985 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8342188953851997 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8343624730701736 at Vector3<0.0, 0.0, 0.0> to 0.8639069213588442 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8657386674870476 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.990406579908961 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8963481590706138 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0959999512231784 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27352311303547305) to band 2 (0.4441276469358833), 47.54528063405649%
# Gap from band 3 (0.5582218046289625) to band 4 (0.5921029038134862), 5.890701805475255%
# Gap from band 4 (0.7888318505845) to band 5 (0.7889383831635985), 0.013504194314208117%
# Gap from band 5 (0.8342188953851997) to band 6 (0.8343624730701736), 0.01720955150145107%
# Gap from band 6 (0.8639069213588442) to band 7 (0.8657386674870476), 0.2118059491512022%
# total elapsed time for run: 0.744255542755127
# done
