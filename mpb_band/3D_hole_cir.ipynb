# %%
from pathlib import Path
import os

script_dir = globals().get("script_dir", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
fig_dir = script_dir / "fig"
out_dir = script_dir / "out"
fig_dir.mkdir(exist_ok=True)
out_dir.mkdir(exist_ok=True)
os.chdir(out_dir)

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_air = 1
n_si = 3.48

#slab厚さ
h = 0.5

#穴半径
r = 0.25

#計算する固有周波数の数
num_bands = 4

#メッシュの細かさ
resolution = 16

#計算間隔
interpolate = 12

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1, 10*h),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))

#構造
#default_material = mp.Medium(epsilon=n_si**2)
geometry = [
    mp.Block(material=mp.Medium(epsilon=n_si**2),
             size=mp.Vector3(mp.inf, mp.inf, h)),
    mp.Cylinder(r, material=mp.Medium(epsilon=n_air**2), height = h)
]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(y=0.5),          # M
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(interpolate, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

#ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
#                               mpb.fix_efield_phase,
#                               mpb.output_efield_z))
#tm_freqs = ms.all_freqs
#tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 16 x 80.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 5)
# Cell volume = 4.33013
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 0.5, axis (0, 0, 1)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 40 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<-0.02564102564102564, 0.02564102564102564, 0.0>
#   Vector3<-0.05128205128205128, 0.05128205128205128, 0.0>
#   Vector3<-0.07692307692307693, 0.07692307692307693, 0.0>
#   Vector3<-0.10256410256410256, 0.10256410256410256, 0.0>
#   Vector3<-0.1282051282051282, 0.1282051282051282, 0.0>
#   Vector3<-0.15384615384615385, 0.15384615384615385, 0.0>
#   Vector3<-0.1794871794871795, 0.1794871794871795, 0.0>
#   Vector3<-0.20512820512820512, 0.20512820512820512, 0.0>
#   Vector3<-0.23076923076923075, 0.23076923076923075, 0.0>
#   Vector3<-0.2564102564102564, 0.2564102564102564, 0.0>
#   Vector3<-0.28205128205128205, 0.28205128205128205, 0.0>
#   Vector3<-0.3076923076923077, 0.3076923076923077, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.30769230769230765, 0.34615384615384615, 0.0>
#   Vector3<-0.28205128205128205, 0.358974358974359, 0.0>
#   Vector3<-0.2564102564102564, 0.3717948717948718, 0.0>
#   Vector3<-0.23076923076923075, 0.3846153846153846, 0.0>
#   Vector3<-0.20512820512820512, 0.3974358974358974, 0.0>
#   Vector3<-0.17948717948717946, 0.41025641025641024, 0.0>
#   Vector3<-0.15384615384615383, 0.4230769230769231, 0.0>
#   Vector3<-0.1282051282051282, 0.4358974358974359, 0.0>
#   Vector3<-0.10256410256410256, 0.4487179487179487, 0.0>
#   Vector3<-0.07692307692307693, 0.46153846153846156, 0.0>
#   Vector3<-0.051282051282051266, 0.47435897435897434, 0.0>
#   Vector3<-0.025641025641025605, 0.48717948717948717, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.46153846153846156, 0.0>
#   Vector3<0.0, 0.4230769230769231, 0.0>
#   Vector3<0.0, 0.3846153846153846, 0.0>
#   Vector3<0.0, 0.34615384615384615, 0.0>
#   Vector3<0.0, 0.3076923076923077, 0.0>
#   Vector3<0.0, 0.2692307692307692, 0.0>
#   Vector3<0.0, 0.23076923076923073, 0.0>
#   Vector3<0.0, 0.1923076923076923, 0.0>
#   Vector3<0.0, 0.15384615384615385, 0.0>
#   Vector3<0.0, 0.11538461538461536, 0.0>
#   Vector3<0.0, 0.07692307692307687, 0.0>
#   Vector3<0.0, 0.038461538461538436, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.06108236312866211
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 13 iterations.
# zevenfreqs:, 1, 0, 0, 0, 0, 0, 0.141366, 0.141384, 0.331349
# elapsed time for k point: 0.30763888359069824
# solve_kpoint (-0.025641,0.025641,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 2, -0.025641, 0.025641, 0, 0.0512821, 0.0384088, 0.147738, 0.149921, 0.334813
# elapsed time for k point: 0.34207749366760254
# solve_kpoint (-0.0512821,0.0512821,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 3, -0.0512821, 0.0512821, 0, 0.102564, 0.0732571, 0.166779, 0.173027, 0.345047
# elapsed time for k point: 0.29875802993774414
# solve_kpoint (-0.0769231,0.0769231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 79 iterations.
# zevenfreqs:, 4, -0.0769231, 0.0769231, 0, 0.153846, 0.102402, 0.197462, 0.205725, 0.361043
# elapsed time for k point: 2.3922641277313232
# solve_kpoint (-0.102564,0.102564,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 23 iterations.
# zevenfreqs:, 5, -0.102564, 0.102564, 0, 0.205128, 0.126583, 0.23657, 0.243993, 0.374261
# elapsed time for k point: 0.6846592426300049
# solve_kpoint (-0.128205,0.128205,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 6, -0.128205, 0.128205, 0, 0.25641, 0.147709, 0.28051, 0.285242, 0.367969
# elapsed time for k point: 0.36405515670776367
# solve_kpoint (-0.153846,0.153846,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 7, -0.153846, 0.153846, 0, 0.307692, 0.167027, 0.32691, 0.327345, 0.361351
# elapsed time for k point: 0.3241269588470459
# solve_kpoint (-0.179487,0.179487,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 20 iterations.
# zevenfreqs:, 8, -0.179487, 0.179487, 0, 0.358974, 0.185091, 0.350363, 0.36204, 0.374137
# elapsed time for k point: 0.6052303314208984
# solve_kpoint (-0.205128,0.205128,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 9, -0.205128, 0.205128, 0, 0.410256, 0.202093, 0.344691, 0.35084, 0.414532
# elapsed time for k point: 0.3526921272277832
# solve_kpoint (-0.230769,0.230769,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# zevenfreqs:, 10, -0.230769, 0.230769, 0, 0.461538, 0.21799, 0.338154, 0.339124, 0.45146
# elapsed time for k point: 0.363755464553833
# solve_kpoint (-0.25641,0.25641,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 37 iterations.
# zevenfreqs:, 11, -0.25641, 0.25641, 0, 0.512821, 0.232477, 0.328419, 0.331885, 0.460902
# elapsed time for k point: 1.0776143074035645
# solve_kpoint (-0.282051,0.282051,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 12, -0.282051, 0.282051, 0, 0.564103, 0.244776, 0.319796, 0.326061, 0.466039
# elapsed time for k point: 0.29358386993408203
# solve_kpoint (-0.307692,0.307692,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 13, -0.307692, 0.307692, 0, 0.615385, 0.253313, 0.315056, 0.320769, 0.470544
# elapsed time for k point: 0.32724547386169434
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 14, -0.333333, 0.333333, 0, 0.666667, 0.256271, 0.316066, 0.316235, 0.472793
# elapsed time for k point: 0.3562612533569336
# solve_kpoint (-0.307692,0.346154,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 15, -0.307692, 0.346154, 0, 0.654223, 0.255642, 0.314088, 0.318999, 0.471966
# elapsed time for k point: 0.3255934715270996
# solve_kpoint (-0.282051,0.358974,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 16, -0.282051, 0.358974, 0, 0.642562, 0.253999, 0.312156, 0.323057, 0.469421
# elapsed time for k point: 0.3226463794708252
# solve_kpoint (-0.25641,0.371795,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 17, -0.25641, 0.371795, 0, 0.631727, 0.251702, 0.31039, 0.327959, 0.465395
# elapsed time for k point: 0.32236480712890625
# solve_kpoint (-0.230769,0.384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 18, -0.230769, 0.384615, 0, 0.621762, 0.249055, 0.308792, 0.33342, 0.460386
# elapsed time for k point: 0.337263822555542
# solve_kpoint (-0.205128,0.397436,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 19, -0.205128, 0.397436, 0, 0.612708, 0.246289, 0.307363, 0.339227, 0.454814
# elapsed time for k point: 0.3299422264099121
# solve_kpoint (-0.179487,0.410256,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 20, -0.179487, 0.410256, 0, 0.604606, 0.243572, 0.306104, 0.345217, 0.448954
# elapsed time for k point: 0.33075761795043945
# solve_kpoint (-0.153846,0.423077,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 21, -0.153846, 0.423077, 0, 0.597496, 0.241026, 0.305016, 0.351262, 0.442992
# elapsed time for k point: 0.311568021774292
# solve_kpoint (-0.128205,0.435897,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 22, -0.128205, 0.435897, 0, 0.591413, 0.238742, 0.304098, 0.357236, 0.437076
# elapsed time for k point: 0.27277207374572754
# solve_kpoint (-0.102564,0.448718,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zevenfreqs:, 23, -0.102564, 0.448718, 0, 0.58639, 0.236789, 0.303348, 0.36299, 0.431364
# elapsed time for k point: 0.25432300567626953
# solve_kpoint (-0.0769231,0.461538,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# zevenfreqs:, 24, -0.0769231, 0.461538, 0, 0.582452, 0.23522, 0.302766, 0.368309, 0.426077
# elapsed time for k point: 0.23037099838256836
# solve_kpoint (-0.0512821,0.474359,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# zevenfreqs:, 25, -0.0512821, 0.474359, 0, 0.579623, 0.234072, 0.302352, 0.372843, 0.421564
# elapsed time for k point: 0.2249007225036621
# solve_kpoint (-0.025641,0.487179,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# zevenfreqs:, 26, -0.025641, 0.487179, 0, 0.577919, 0.233372, 0.302102, 0.376042, 0.418378
# elapsed time for k point: 0.22579026222229004
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# zevenfreqs:, 27, 0, 0.5, 0, 0.57735, 0.233137, 0.302018, 0.377231, 0.417193
# elapsed time for k point: 0.21852374076843262
# solve_kpoint (0,0.461538,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zevenfreqs:, 28, 0, 0.461538, 0, 0.532939, 0.230075, 0.304739, 0.377623, 0.417075
# elapsed time for k point: 0.25974392890930176
# solve_kpoint (0,0.423077,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 29, 0, 0.423077, 0, 0.488527, 0.222002, 0.311766, 0.378794, 0.416494
# elapsed time for k point: 0.34297657012939453
# solve_kpoint (0,0.384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 30, 0, 0.384615, 0, 0.444116, 0.2108, 0.321139, 0.380756, 0.413923
# elapsed time for k point: 0.32216835021972656
# solve_kpoint (0,0.346154,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 31, 0, 0.346154, 0, 0.399704, 0.197716, 0.331459, 0.383491, 0.399393
# elapsed time for k point: 0.47542858123779297
# solve_kpoint (0,0.307692,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 27 iterations.
# zevenfreqs:, 32, 0, 0.307692, 0, 0.355292, 0.183357, 0.341734, 0.367127, 0.372034
# elapsed time for k point: 0.8126497268676758
# solve_kpoint (0,0.269231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 13 iterations.
# zevenfreqs:, 33, 0, 0.269231, 0, 0.310881, 0.167958, 0.329586, 0.330612, 0.352971
# elapsed time for k point: 0.42757129669189453
# solve_kpoint (0,0.230769,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 13 iterations.
# zevenfreqs:, 34, 0, 0.230769, 0, 0.266469, 0.151514, 0.289444, 0.29363, 0.362037
# elapsed time for k point: 0.42206549644470215
# solve_kpoint (0,0.192308,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 35, 0, 0.192308, 0, 0.222058, 0.13377, 0.250674, 0.257409, 0.370201
# elapsed time for k point: 0.4588050842285156
# solve_kpoint (0,0.153846,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 17 iterations.
# zevenfreqs:, 36, 0, 0.153846, 0, 0.177646, 0.1141, 0.214801, 0.222987, 0.36962
# elapsed time for k point: 0.4957001209259033
# solve_kpoint (0,0.115385,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 13 iterations.
# zevenfreqs:, 37, 0, 0.115385, 0, 0.133235, 0.0913754, 0.183893, 0.19173, 0.354093
# elapsed time for k point: 0.40738868713378906
# solve_kpoint (0,0.0769231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 38, 0, 0.0769231, 0, 0.0888231, 0.0644336, 0.160449, 0.165695, 0.341668
# elapsed time for k point: 0.3257720470428467
# solve_kpoint (0,0.0384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 39, 0, 0.0384615, 0, 0.0444116, 0.0333942, 0.146144, 0.147834, 0.333949
# elapsed time for k point: 0.3915407657623291
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 11 iterations.
# zevenfreqs:, 40, 0, 0, 0, 0, 0, 0.141366, 0.141384, 0.331349
# elapsed time for k point: 0.26583051681518555
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.25627068937327735 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.14136607532535778 at Vector3<0.0, 0.0, 0.0> to 0.3503633035734396 at Vector3<-0.1794871794871795, 0.1794871794871795, 0.0>
# Band 3 range: 0.14138394458385498 at Vector3<0.0, 0.0, 0.0> to 0.38349104263214545 at Vector3<0.0, 0.34615384615384615, 0.0>
# Band 4 range: 0.33134874218592164 at Vector3<0.0, 0.0, 0.0> to 0.47279263329271665 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 17.27109956741333
# done

# %%
md = mpb.MPBData(rectify=True, periods=5, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-12.1104, mean 1.86205, harm. mean 1.08942, 9.40918% > 1, 7.75898% "fill"
# (160, 139, 800)

# %%
#import csv
#with open(out_dir / 'epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps[:,:,400], interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(16, 16))
sns.heatmap(converted_eps[:,:,200], annot=True, fmt=".1f", square=True, cmap = "YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-a6351ceb6276> in <module>
# ----> 1 import seaborn as sns
#       2
#       3 plt.figure(figsize=(16, 16))
#       4 sns.heatmap(converted_eps[:,:,200], annot=True, fmt=".1f", square=True, cmap = "YlGnBu")
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps[:,:,200].T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 16 x 80.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 5)
# Cell volume = 4.33013
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 0.5, axis (0, 0, 1)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 40 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<-0.02564102564102564, 0.02564102564102564, 0.0>
#   Vector3<-0.05128205128205128, 0.05128205128205128, 0.0>
#   Vector3<-0.07692307692307693, 0.07692307692307693, 0.0>
#   Vector3<-0.10256410256410256, 0.10256410256410256, 0.0>
#   Vector3<-0.1282051282051282, 0.1282051282051282, 0.0>
#   Vector3<-0.15384615384615385, 0.15384615384615385, 0.0>
#   Vector3<-0.1794871794871795, 0.1794871794871795, 0.0>
#   Vector3<-0.20512820512820512, 0.20512820512820512, 0.0>
#   Vector3<-0.23076923076923075, 0.23076923076923075, 0.0>
#   Vector3<-0.2564102564102564, 0.2564102564102564, 0.0>
#   Vector3<-0.28205128205128205, 0.28205128205128205, 0.0>
#   Vector3<-0.3076923076923077, 0.3076923076923077, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.30769230769230765, 0.34615384615384615, 0.0>
#   Vector3<-0.28205128205128205, 0.358974358974359, 0.0>
#   Vector3<-0.2564102564102564, 0.3717948717948718, 0.0>
#   Vector3<-0.23076923076923075, 0.3846153846153846, 0.0>
#   Vector3<-0.20512820512820512, 0.3974358974358974, 0.0>
#   Vector3<-0.17948717948717946, 0.41025641025641024, 0.0>
#   Vector3<-0.15384615384615383, 0.4230769230769231, 0.0>
#   Vector3<-0.1282051282051282, 0.4358974358974359, 0.0>
#   Vector3<-0.10256410256410256, 0.4487179487179487, 0.0>
#   Vector3<-0.07692307692307693, 0.46153846153846156, 0.0>
#   Vector3<-0.051282051282051266, 0.47435897435897434, 0.0>
#   Vector3<-0.025641025641025605, 0.48717948717948717, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.46153846153846156, 0.0>
#   Vector3<0.0, 0.4230769230769231, 0.0>
#   Vector3<0.0, 0.3846153846153846, 0.0>
#   Vector3<0.0, 0.34615384615384615, 0.0>
#   Vector3<0.0, 0.3076923076923077, 0.0>
#   Vector3<0.0, 0.2692307692307692, 0.0>
#   Vector3<0.0, 0.23076923076923073, 0.0>
#   Vector3<0.0, 0.1923076923076923, 0.0>
#   Vector3<0.0, 0.15384615384615385, 0.0>
#   Vector3<0.0, 0.11538461538461536, 0.0>
#   Vector3<0.0, 0.07692307692307687, 0.0>
#   Vector3<0.0, 0.038461538461538436, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.05284595489501953
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 15 iterations.
# zoddfreqs:, 1, 0, 0, 0, 0, 0, 0.193376, 0.193387, 0.329059
# elapsed time for k point: 0.3556685447692871
# solve_kpoint (-0.025641,0.025641,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 2, -0.025641, 0.025641, 0, 0.0512821, 0.0489583, 0.198258, 0.19949, 0.331138
# elapsed time for k point: 0.3628654479980469
# solve_kpoint (-0.0512821,0.0512821,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 72 iterations.
# zoddfreqs:, 3, -0.0512821, 0.0512821, 0, 0.102564, 0.0974756, 0.212038, 0.216628, 0.337109
# elapsed time for k point: 2.020778179168701
# solve_kpoint (-0.0769231,0.0769231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 35 iterations.
# zoddfreqs:, 4, -0.0769231, 0.0769231, 0, 0.153846, 0.144837, 0.232734, 0.241996, 0.346698
# elapsed time for k point: 0.9755592346191406
# solve_kpoint (-0.102564,0.102564,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 20 iterations.
# zoddfreqs:, 5, -0.102564, 0.102564, 0, 0.205128, 0.189533, 0.258694, 0.272286, 0.359759
# elapsed time for k point: 0.5850257873535156
# solve_kpoint (-0.128205,0.128205,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 6, -0.128205, 0.128205, 0, 0.25641, 0.228521, 0.29018, 0.303914, 0.376737
# elapsed time for k point: 0.3450005054473877
# solve_kpoint (-0.153846,0.153846,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 7, -0.153846, 0.153846, 0, 0.307692, 0.258671, 0.328588, 0.332614, 0.393451
# elapsed time for k point: 0.5709095001220703
# solve_kpoint (-0.179487,0.179487,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 8, -0.179487, 0.179487, 0, 0.358974, 0.280789, 0.354589, 0.372596, 0.390395
# elapsed time for k point: 0.37967610359191895
# solve_kpoint (-0.205128,0.205128,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 26 iterations.
# zoddfreqs:, 9, -0.205128, 0.205128, 0, 0.410256, 0.29788, 0.36749, 0.38901, 0.402259
# elapsed time for k point: 0.770585298538208
# solve_kpoint (-0.230769,0.230769,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 10, -0.230769, 0.230769, 0, 0.461538, 0.312089, 0.368968, 0.394032, 0.395731
# elapsed time for k point: 0.35561704635620117
# solve_kpoint (-0.25641,0.25641,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 11, -0.25641, 0.25641, 0, 0.512821, 0.324577, 0.365354, 0.385742, 0.405468
# elapsed time for k point: 0.32337188720703125
# solve_kpoint (-0.282051,0.282051,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 12, -0.282051, 0.282051, 0, 0.564103, 0.33591, 0.360997, 0.377801, 0.414009
# elapsed time for k point: 0.33913159370422363
# solve_kpoint (-0.307692,0.307692,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 13, -0.307692, 0.307692, 0, 0.615385, 0.346103, 0.356863, 0.370729, 0.419753
# elapsed time for k point: 0.36347532272338867
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 14, -0.333333, 0.333333, 0, 0.666667, 0.353204, 0.353241, 0.366824, 0.421695
# elapsed time for k point: 0.41644906997680664
# Fixing e-field (band 1) phase by -0.00122142 + -0.999999i; max ampl. = 1.13634
# Fixing e-field (band 2) phase by -0.0400727 + 0.999197i; max ampl. = 0.726018
# Fixing e-field (band 3) phase by 0.999986 + 0.00528635i; max ampl. = 0.683362
# Fixing e-field (band 4) phase by -0.977728 + 0.209875i; max ampl. = 0.873275
# solve_kpoint (-0.307692,0.346154,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 15, -0.307692, 0.346154, 0, 0.654223, 0.351623, 0.353548, 0.368223, 0.421266
# elapsed time for k point: 0.39786696434020996
# solve_kpoint (-0.282051,0.358974,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zoddfreqs:, 16, -0.282051, 0.358974, 0, 0.642562, 0.350195, 0.351928, 0.371665, 0.420095
# elapsed time for k point: 0.3225255012512207
# solve_kpoint (-0.25641,0.371795,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zoddfreqs:, 17, -0.25641, 0.371795, 0, 0.631727, 0.348928, 0.349607, 0.375936, 0.418384
# elapsed time for k point: 0.31890249252319336
# solve_kpoint (-0.230769,0.384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zoddfreqs:, 18, -0.230769, 0.384615, 0, 0.621762, 0.347137, 0.347835, 0.380486, 0.416324
# elapsed time for k point: 0.3179588317871094
# solve_kpoint (-0.205128,0.397436,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zoddfreqs:, 19, -0.205128, 0.397436, 0, 0.612708, 0.344753, 0.346892, 0.385105, 0.414085
# elapsed time for k point: 0.3198120594024658
# solve_kpoint (-0.179487,0.410256,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 10 iterations.
# zoddfreqs:, 20, -0.179487, 0.410256, 0, 0.604606, 0.342538, 0.346106, 0.389694, 0.411805
# elapsed time for k point: 0.3190484046936035
# solve_kpoint (-0.153846,0.423077,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 21, -0.153846, 0.423077, 0, 0.597496, 0.340548, 0.345466, 0.394182, 0.4096
# elapsed time for k point: 0.34520459175109863
# solve_kpoint (-0.128205,0.435897,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 22, -0.128205, 0.435897, 0, 0.591413, 0.338817, 0.34496, 0.398493, 0.407568
# elapsed time for k point: 0.33441877365112305
# solve_kpoint (-0.102564,0.448718,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 23, -0.102564, 0.448718, 0, 0.58639, 0.33737, 0.344575, 0.40253, 0.40579
# elapsed time for k point: 0.3527712821960449
# solve_kpoint (-0.0769231,0.461538,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 24, -0.0769231, 0.461538, 0, 0.582452, 0.336226, 0.344296, 0.404333, 0.406145
# elapsed time for k point: 0.3460829257965088
# solve_kpoint (-0.0512821,0.474359,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 25, -0.0512821, 0.474359, 0, 0.579623, 0.3354, 0.344108, 0.403252, 0.409113
# elapsed time for k point: 0.34035801887512207
# solve_kpoint (-0.025641,0.487179,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 26, -0.025641, 0.487179, 0, 0.577919, 0.3349, 0.344001, 0.402587, 0.411122
# elapsed time for k point: 0.3188161849975586
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 27, 0, 0.5, 0, 0.57735, 0.334733, 0.343967, 0.402362, 0.411843
# elapsed time for k point: 0.3524153232574463
# solve_kpoint (0,0.461538,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 28, 0, 0.461538, 0, 0.532939, 0.328517, 0.34972, 0.398663, 0.41429
# elapsed time for k point: 0.32918620109558105
# solve_kpoint (0,0.423077,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 29, 0, 0.423077, 0, 0.488527, 0.318613, 0.358158, 0.391112, 0.418117
# elapsed time for k point: 0.331012487411499
# solve_kpoint (0,0.384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 30, 0, 0.384615, 0, 0.444116, 0.307413, 0.366625, 0.381388, 0.421646
# elapsed time for k point: 0.3634331226348877
# solve_kpoint (0,0.346154,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 87 iterations.
# zoddfreqs:, 31, 0, 0.346154, 0, 0.399704, 0.294623, 0.369322, 0.374842, 0.410198
# elapsed time for k point: 2.500521659851074
# solve_kpoint (0,0.307692,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zoddfreqs:, 32, 0, 0.307692, 0, 0.355292, 0.279397, 0.354057, 0.368983, 0.383625
# elapsed time for k point: 0.2816140651702881
# solve_kpoint (0,0.269231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 14 iterations.
# zoddfreqs:, 33, 0, 0.269231, 0, 0.310881, 0.260253, 0.331166, 0.334343, 0.390783
# elapsed time for k point: 0.42505788803100586
# solve_kpoint (0,0.230769,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 86 iterations.
# zoddfreqs:, 34, 0, 0.230769, 0, 0.266469, 0.235179, 0.297153, 0.309931, 0.381172
# elapsed time for k point: 2.8966288566589355
# solve_kpoint (0,0.192308,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zoddfreqs:, 35, 0, 0.192308, 0, 0.222058, 0.203229, 0.268399, 0.282768, 0.365
# elapsed time for k point: 0.33811521530151367
# solve_kpoint (0,0.153846,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 36, 0, 0.153846, 0, 0.177646, 0.166056, 0.244174, 0.255642, 0.352328
# elapsed time for k point: 0.3656165599822998
# solve_kpoint (0,0.115385,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zoddfreqs:, 37, 0, 0.115385, 0, 0.133235, 0.12601, 0.22372, 0.231015, 0.342408
# elapsed time for k point: 0.2833733558654785
# solve_kpoint (0,0.0769231,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zoddfreqs:, 38, 0, 0.0769231, 0, 0.0888231, 0.0845505, 0.20758, 0.211093, 0.335121
# elapsed time for k point: 0.2694551944732666
# solve_kpoint (0,0.0384615,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# zoddfreqs:, 39, 0, 0.0384615, 0, 0.0444116, 0.0424138, 0.197054, 0.197981, 0.330624
# elapsed time for k point: 0.27831435203552246
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 11 iterations.
# zoddfreqs:, 40, 0, 0, 0, 0, 0, 0.193376, 0.193387, 0.329041
# elapsed time for k point: 0.2835655212402344
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3532041472741454 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.19337551270350653 at Vector3<0.0, 0.0, 0.0> to 0.36932204918266726 at Vector3<0.0, 0.34615384615384615, 0.0>
# Band 3 range: 0.1933867300840396 at Vector3<0.0, 0.0, 0.0> to 0.40433263330494806 at Vector3<-0.07692307692307693, 0.46153846153846156, 0.0>
# Band 4 range: 0.32904050222834086 at Vector3<0.0, 0.0, 0.0> to 0.421694957924798 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 21.57780122756958
# done
# /home/kyaakakkoii/.conda/envs/mp/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: No contour levels were found within the data range.

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_t_hz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_t_hz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_t_hz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_t_hz, color='navy')
ax.set_ylim([te_freqs_t_hz.min(), te_freqs_t_hz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_t_hz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()

# %%
def lightline_hex(k):
    y = []
    for i in range(len(k)):
        kmod = np.mod(k[i],3)
        y.append(2/3 * kmod * (0 <= kmod < 1) + 1/2*np.sqrt(1/9*(kmod-5)**2 + 1/3*(kmod-1)**2) * (1 <= kmod < 2) + 1/(np.sqrt(3))*(3-kmod) * (2 <= kmod < 3))
    
    y = np.array(y)
    return y

# %%
fs = 20

fig, ax = plt.subplots(figsize=(6,6))

x = range(len(te_freqs))

#ax.plot(tm_freqs, color='gray')
ax.plot(te_freqs, color='black')
ax.set_ylim([te_freqs.min(), te_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='black', alpha=0.2)

#for gap in te_gaps:
#    if gap[0] > 1:
#        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TE bands', color='black', size=fs)
#ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fs)
ax.set_ylabel('frequency (c/a)', size=fs)
ax.grid(True)
plt.tick_params(labelsize=fs)
plt.savefig(fig_dir / "3D_circle.png", bbox_inches="tight")

plt.show()
