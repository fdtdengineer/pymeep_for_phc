# %%
from pathlib import Path
import os

SCRIPT_DIR = globals().get("SCRIPT_DIR", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
FIG_DIR = SCRIPT_DIR / "fig"
OUT_DIR = SCRIPT_DIR / "out"
FIG_DIR.mkdir(exist_ok=True)
OUT_DIR.mkdir(exist_ok=True)
os.chdir(OUT_DIR)

# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    widthPhC = 20
    ConnectionWaveguide = 5
    wgi = 1
    r = 1/4
    n_eff = 2.6
    fcen = 0.3 
    df = 0.1
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16
    T_decay = 10000
    
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)
    eps = n_eff**2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                         center=mp.Vector3(),
                         material=mp.Medium(epsilon=eps))
    geometry = [waveguide]

    # PhC
    if PhC:
        # slab
        blk = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                             center=mp.Vector3(),
                             material=mp.Medium(epsilon=eps))

        geometry.append(blk)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-Nx/2, wgi*np.sqrt(3)/2 + shift_y*j)))
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-Nx/2, -(wgi*np.sqrt(3)/2 + shift_y*j))))

                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-(Nx+1)/2, wgi*np.sqrt(3)/2 + shift_y*(j+1/2))))
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-(Nx+1)/2, -(wgi*np.sqrt(3)/2 + shift_y*(j+1/2)))))
                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))
    
    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                         component=mp.Hz,
                         center=mp.Vector3(-length/2 +1,0),
                         size=mp.Vector3(0,wgi*np.sqrt(3)))
              ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=150)
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 40, decay_check=20)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00151205 s
# Working in 2D dimensions.
# Computational cell is 30 x 34.625 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,1.73205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.204138 s
# -----------
# Meep progress: 103.34375/10000.0 = 1.0% done in 4.0s, 383.3s to go
# on time step 3307 (time=103.344), 0.00121046 s/step
# Meep progress: 202.625/10000.0 = 2.0% done in 8.0s, 387.0s to go
# on time step 6485 (time=202.656), 0.00125887 s/step
# Meep progress: 278.34375/10000.0 = 2.8% done in 12.0s, 419.3s to go
# on time step 8909 (time=278.406), 0.0016502 s/step
# Meep progress: 384.6875/10000.0 = 3.8% done in 16.0s, 400.1s to go
# on time step 12312 (time=384.75), 0.00117549 s/step
# Meep progress: 483.1875/10000.0 = 4.8% done in 20.0s, 394.0s to go
# on time step 15464 (time=483.25), 0.00126916 s/step
# Meep progress: 595.8125/10000.0 = 6.0% done in 24.0s, 378.9s to go
# on time step 19069 (time=595.906), 0.00110967 s/step
# Meep progress: 710.3125/10000.0 = 7.1% done in 28.0s, 366.3s to go
# on time step 22733 (time=710.406), 0.00109177 s/step
# Meep progress: 825.125/10000.0 = 8.3% done in 32.0s, 355.9s to go
# on time step 26405 (time=825.156), 0.00108954 s/step
# Meep progress: 932.25/10000.0 = 9.3% done in 36.0s, 350.3s to go
# on time step 29835 (time=932.344), 0.00116627 s/step
# Meep progress: 1024.96875/10000.0 = 10.2% done in 40.0s, 350.3s to go
# on time step 32802 (time=1025.06), 0.00134821 s/step
# Meep progress: 1128.34375/10000.0 = 11.3% done in 44.0s, 346.0s to go
# on time step 36112 (time=1128.5), 0.00120869 s/step
# Meep progress: 1236.875/10000.0 = 12.4% done in 48.0s, 340.2s to go
# on time step 39583 (time=1236.97), 0.00115249 s/step
# Meep progress: 1340.375/10000.0 = 13.4% done in 52.0s, 336.0s to go
# on time step 42896 (time=1340.5), 0.00120776 s/step
# Meep progress: 1438.1875/10000.0 = 14.4% done in 56.0s, 333.5s to go
# on time step 46028 (time=1438.38), 0.00127728 s/step
# Meep progress: 1559.6875/10000.0 = 15.6% done in 60.0s, 324.8s to go
# on time step 49915 (time=1559.84), 0.00102922 s/step
# Meep progress: 1666.40625/10000.0 = 16.7% done in 64.0s, 320.1s to go
# on time step 53331 (time=1666.59), 0.00117097 s/step
# Meep progress: 1787.0625/10000.0 = 17.9% done in 68.0s, 312.6s to go
# on time step 57192 (time=1787.25), 0.00103627 s/step
# Meep progress: 1856.40625/10000.0 = 18.6% done in 72.0s, 315.9s to go
# on time step 59408 (time=1856.5), 0.00180516 s/step
# Meep progress: 1934.59375/10000.0 = 19.3% done in 76.0s, 316.9s to go
# on time step 61916 (time=1934.88), 0.00159528 s/step
# Meep progress: 2038.125/10000.0 = 20.4% done in 80.0s, 312.6s to go
# on time step 65228 (time=2038.38), 0.00120792 s/step
# Meep progress: 2160.0/10000.0 = 21.6% done in 84.0s, 305.0s to go
# on time step 69129 (time=2160.28), 0.00102551 s/step
# Meep progress: 2280.65625/10000.0 = 22.8% done in 88.0s, 297.9s to go
# on time step 72991 (time=2280.97), 0.00103577 s/step
# Meep progress: 2404.71875/10000.0 = 24.0% done in 92.0s, 290.6s to go
# on time step 76957 (time=2404.91), 0.00100875 s/step
# Meep progress: 2519.4375/10000.0 = 25.2% done in 96.0s, 285.1s to go
# on time step 80629 (time=2519.66), 0.00108945 s/step
# Meep progress: 2630.09375/10000.0 = 26.3% done in 100.0s, 280.3s to go
# on time step 84174 (time=2630.44), 0.0011285 s/step
# Meep progress: 2745.25/10000.0 = 27.5% done in 104.0s, 274.9s to go
# on time step 87859 (time=2745.59), 0.00108569 s/step
# Meep progress: 2873.1875/10000.0 = 28.7% done in 108.0s, 267.9s to go
# on time step 91949 (time=2873.41), 0.000978142 s/step
# Meep progress: 2986.15625/10000.0 = 29.9% done in 112.0s, 263.1s to go
# on time step 95568 (time=2986.5), 0.00110538 s/step
# Meep progress: 3101.8125/10000.0 = 31.0% done in 116.0s, 258.0s to go
# on time step 99272 (time=3102.25), 0.00108004 s/step
# Meep progress: 3216.0625/10000.0 = 32.2% done in 120.0s, 253.2s to go
# on time step 102925 (time=3216.41), 0.00109514 s/step
# Meep progress: 3326.75/10000.0 = 33.3% done in 124.0s, 248.8s to go
# on time step 106467 (time=3327.09), 0.00112933 s/step
# Meep progress: 3437.75/10000.0 = 34.4% done in 128.0s, 244.4s to go
# on time step 110023 (time=3438.22), 0.00112509 s/step
# Meep progress: 3569.375/10000.0 = 35.7% done in 132.0s, 237.9s to go
# on time step 114236 (time=3569.88), 0.000949642 s/step
# Meep progress: 3701.0/10000.0 = 37.0% done in 136.0s, 231.5s to go
# on time step 118447 (time=3701.47), 0.000950053 s/step
# Meep progress: 3811.21875/10000.0 = 38.1% done in 140.0s, 227.4s to go
# on time step 121970 (time=3811.56), 0.00113558 s/step
# Meep progress: 3918.625/10000.0 = 39.2% done in 144.0s, 223.5s to go
# on time step 125409 (time=3919.03), 0.0011634 s/step
# Meep progress: 4026.71875/10000.0 = 40.3% done in 148.0s, 219.6s to go
# on time step 128867 (time=4027.09), 0.00115685 s/step
# Meep progress: 4129.4375/10000.0 = 41.3% done in 152.0s, 216.1s to go
# on time step 132150 (time=4129.69), 0.00121909 s/step
# Meep progress: 4222.25/10000.0 = 42.2% done in 156.0s, 213.5s to go
# on time step 135123 (time=4222.59), 0.00134593 s/step
# Meep progress: 4322.28125/10000.0 = 43.2% done in 160.0s, 210.2s to go
# on time step 138332 (time=4322.88), 0.00124661 s/step
# Meep progress: 4414.84375/10000.0 = 44.1% done in 164.0s, 207.5s to go
# on time step 141280 (time=4415), 0.00135897 s/step
# Meep progress: 4507.25/10000.0 = 45.1% done in 168.0s, 204.8s to go
# on time step 144253 (time=4507.91), 0.00134607 s/step
# Meep progress: 4616.6875/10000.0 = 46.2% done in 172.0s, 200.6s to go
# on time step 147764 (time=4617.62), 0.00113948 s/step
# Meep progress: 4726.9375/10000.0 = 47.3% done in 176.0s, 196.4s to go
# on time step 151290 (time=4727.81), 0.00113464 s/step
# Meep progress: 4837.125/10000.0 = 48.4% done in 180.0s, 192.2s to go
# on time step 154818 (time=4838.06), 0.00113392 s/step
# Meep progress: 4932.90625/10000.0 = 49.3% done in 184.0s, 189.0s to go
# on time step 157885 (time=4933.91), 0.00130433 s/step
# Meep progress: 5019.09375/10000.0 = 50.2% done in 188.0s, 186.6s to go
# on time step 160630 (time=5019.69), 0.0014577 s/step
# Meep progress: 5101.3125/10000.0 = 51.0% done in 192.0s, 184.4s to go
# on time step 163257 (time=5101.78), 0.00152301 s/step
# Meep progress: 5192.9375/10000.0 = 51.9% done in 196.0s, 181.5s to go
# on time step 166205 (time=5193.91), 0.00135723 s/step
# Meep progress: 5286.34375/10000.0 = 52.9% done in 200.0s, 178.4s to go
# on time step 169179 (time=5286.84), 0.00134579 s/step
# Meep progress: 5387.34375/10000.0 = 53.9% done in 204.0s, 174.7s to go
# on time step 172431 (time=5388.47), 0.00123025 s/step
# Meep progress: 5510.21875/10000.0 = 55.1% done in 208.0s, 169.5s to go
# on time step 176371 (time=5511.59), 0.00101526 s/step
# Meep progress: 5607.96875/10000.0 = 56.1% done in 212.0s, 166.1s to go
# on time step 179488 (time=5609), 0.00128346 s/step
# Meep progress: 5697.03125/10000.0 = 57.0% done in 216.0s, 163.2s to go
# on time step 182344 (time=5698.25), 0.0014007 s/step
# Meep progress: 5795.4375/10000.0 = 58.0% done in 220.1s, 159.6s to go
# on time step 185488 (time=5796.5), 0.00127259 s/step
# Meep progress: 5883.1875/10000.0 = 58.8% done in 224.1s, 156.8s to go
# on time step 188285 (time=5883.91), 0.00143069 s/step
# Meep progress: 5992.5625/10000.0 = 59.9% done in 228.1s, 152.5s to go
# on time step 191796 (time=5993.62), 0.00113988 s/step
# Meep progress: 6102.75/10000.0 = 61.0% done in 232.1s, 148.2s to go
# on time step 195327 (time=6103.97), 0.00113304 s/step
# Meep progress: 6206.21875/10000.0 = 62.1% done in 236.1s, 144.3s to go
# on time step 198636 (time=6207.38), 0.00120916 s/step
# Meep progress: 6309.46875/10000.0 = 63.1% done in 240.1s, 140.4s to go
# on time step 201947 (time=6310.84), 0.00120834 s/step
# Meep progress: 6421.5/10000.0 = 64.2% done in 244.1s, 136.0s to go
# on time step 205531 (time=6422.84), 0.00111634 s/step
# Meep progress: 6521.25/10000.0 = 65.2% done in 248.1s, 132.3s to go
# on time step 208720 (time=6522.5), 0.00125454 s/step
# Meep progress: 6617.90625/10000.0 = 66.2% done in 252.1s, 128.8s to go
# on time step 211808 (time=6619), 0.00129574 s/step
# Meep progress: 6702.125/10000.0 = 67.0% done in 256.1s, 126.0s to go
# on time step 214503 (time=6703.22), 0.00148463 s/step
# Meep progress: 6802.46875/10000.0 = 68.0% done in 260.1s, 122.2s to go
# on time step 217721 (time=6803.78), 0.00124329 s/step
# Meep progress: 6906.75/10000.0 = 69.1% done in 264.1s, 118.3s to go
# on time step 221041 (time=6907.53), 0.00120483 s/step
# Meep progress: 7019.21875/10000.0 = 70.2% done in 268.1s, 113.8s to go
# on time step 224661 (time=7020.66), 0.00110512 s/step
# Meep progress: 7125.25/10000.0 = 71.3% done in 272.1s, 109.8s to go
# on time step 228044 (time=7126.38), 0.00118275 s/step
# Meep progress: 7230.0625/10000.0 = 72.3% done in 276.1s, 105.8s to go
# on time step 231407 (time=7231.47), 0.00118985 s/step
# Meep progress: 7335.0/10000.0 = 73.3% done in 280.1s, 101.8s to go
# on time step 234775 (time=7336.72), 0.00118774 s/step
# Meep progress: 7467.46875/10000.0 = 74.7% done in 284.1s, 96.3s to go
# on time step 239013 (time=7469.16), 0.000943904 s/step
# Meep progress: 7596.1875/10000.0 = 76.0% done in 288.1s, 91.2s to go
# on time step 243125 (time=7597.66), 0.000972781 s/step
# Meep progress: 7728.78125/10000.0 = 77.3% done in 292.1s, 85.8s to go
# on time step 247376 (time=7730.5), 0.000940964 s/step
# Meep progress: 7855.5625/10000.0 = 78.6% done in 296.1s, 80.8s to go
# on time step 251433 (time=7857.28), 0.000986136 s/step
# Meep progress: 7983.6875/10000.0 = 79.8% done in 300.1s, 75.8s to go
# on time step 255525 (time=7985.16), 0.000977834 s/step
# Meep progress: 8092.90625/10000.0 = 80.9% done in 304.1s, 71.7s to go
# on time step 259013 (time=8094.16), 0.00114712 s/step
# Meep progress: 8196.25/10000.0 = 82.0% done in 308.1s, 67.8s to go
# on time step 262332 (time=8197.88), 0.0012052 s/step
# Meep progress: 8307.5625/10000.0 = 83.1% done in 312.1s, 63.6s to go
# on time step 265897 (time=8309.28), 0.00112217 s/step
# Meep progress: 8414.15625/10000.0 = 84.1% done in 316.1s, 59.6s to go
# on time step 269290 (time=8415.31), 0.00117913 s/step
# Meep progress: 8494.3125/10000.0 = 84.9% done in 320.1s, 56.7s to go
# on time step 271859 (time=8495.59), 0.00155715 s/step
# Meep progress: 8598.90625/10000.0 = 86.0% done in 324.1s, 52.8s to go
# on time step 275221 (time=8600.66), 0.00118993 s/step
# Meep progress: 8709.40625/10000.0 = 87.1% done in 328.1s, 48.6s to go
# on time step 278753 (time=8711.03), 0.0011327 s/step
# Meep progress: 8805.40625/10000.0 = 88.1% done in 332.1s, 45.1s to go
# on time step 281812 (time=8806.62), 0.00130859 s/step
# Meep progress: 8896.125/10000.0 = 89.0% done in 336.1s, 41.7s to go
# on time step 284722 (time=8897.56), 0.00137464 s/step
# Meep progress: 8987.6875/10000.0 = 89.9% done in 340.1s, 38.3s to go
# on time step 287647 (time=8988.97), 0.00136759 s/step
# Meep progress: 9105.5625/10000.0 = 91.1% done in 344.1s, 33.8s to go
# on time step 291439 (time=9107.47), 0.00105507 s/step
# Meep progress: 9235.71875/10000.0 = 92.4% done in 348.1s, 28.8s to go
# on time step 295595 (time=9237.34), 0.000962636 s/step
# Meep progress: 9363.03125/10000.0 = 93.6% done in 352.1s, 24.0s to go
# on time step 299680 (time=9365), 0.000979274 s/step
# Meep progress: 9469.375/10000.0 = 94.7% done in 356.1s, 20.0s to go
# on time step 303040 (time=9470), 0.00119058 s/step
# Meep progress: 9550.46875/10000.0 = 95.5% done in 360.1s, 16.9s to go
# on time step 305644 (time=9551.38), 0.00153632 s/step
# Meep progress: 9634.21875/10000.0 = 96.3% done in 364.1s, 13.8s to go
# on time step 308353 (time=9636.03), 0.00147662 s/step
# Meep progress: 9735.0625/10000.0 = 97.4% done in 368.1s, 10.0s to go
# on time step 311533 (time=9735.41), 0.00125969 s/step
# Meep progress: 9789.375/10000.0 = 97.9% done in 372.1s, 8.0s to go
# on time step 313315 (time=9791.09), 0.00224491 s/step
# Meep progress: 9898.78125/10000.0 = 99.0% done in 376.1s, 3.8s to go
# on time step 316835 (time=9901.09), 0.00113644 s/step
# Meep progress: 9989.8125/10000.0 = 99.9% done in 380.1s, 0.4s to go
# on time step 319713 (time=9991.03), 0.00139113 s/step
# run 0 finished at t = 10000.0 (320000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00108218 s
# Working in 2D dimensions.
# Computational cell is 50 x 34.625 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,1.73205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,0,0)
#           size (40,34.641,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      cylinder, center = (-20,0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20,-0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20.5,1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20.5,-1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19,0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19,-0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19.5,1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19.5,-1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 3272 objects not shown)...
# time for set_epsilon = 5.7068 s
# -----------
# 0223522 s/step
# Meep progress: 1564.65625/10000.0 = 15.6% done in 132.0s, 711.9s to go
# on time step 50080 (time=1565), 0.00254688 s/step
# Meep progress: 1599.4375/10000.0 = 16.0% done in 136.0s, 714.6s to go
# on time step 51194 (time=1599.81), 0.00359334 s/step
# Meep progress: 1642.3125/10000.0 = 16.4% done in 140.1s, 712.7s to go
# on time step 52568 (time=1642.75), 0.00291265 s/step
# Meep progress: 1689.9375/10000.0 = 16.9% done in 144.1s, 708.4s to go
# on time step 54093 (time=1690.41), 0.00262419 s/step
# Meep progress: 1743.1875/10000.0 = 17.4% done in 148.1s, 701.3s to go
# on time step 55798 (time=1743.69), 0.00234676 s/step
# Meep progress: 1795.46875/10000.0 = 18.0% done in 152.1s, 694.8s to go
# on time step 57471 (time=1795.97), 0.0023914 s/step
# Meep progress: 1850.90625/10000.0 = 18.5% done in 156.1s, 687.1s to go
# on time step 59246 (time=1851.44), 0.00225454 s/step
# Meep progress: 1905.09375/10000.0 = 19.1% done in 160.1s, 680.1s to go
# on time step 60980 (time=1905.62), 0.00230743 s/step
# Meep progress: 1960.34375/10000.0 = 19.6% done in 164.1s, 672.8s to go
# on time step 62748 (time=1960.88), 0.0022628 s/step
# Meep progress: 2015.9375/10000.0 = 20.2% done in 168.1s, 665.6s to go
# on time step 64527 (time=2016.47), 0.00224987 s/step
# Meep progress: 2070.46875/10000.0 = 20.7% done in 172.1s, 659.0s to go
# on time step 66272 (time=2071), 0.00229254 s/step
# Meep progress: 2120.71875/10000.0 = 21.2% done in 176.1s, 654.1s to go
# on time step 67880 (time=2121.25), 0.00248878 s/step
# Meep progress: 2171.0/10000.0 = 21.7% done in 180.1s, 649.3s to go
# on time step 69489 (time=2171.53), 0.00248738 s/step
# Meep progress: 2220.8125/10000.0 = 22.2% done in 184.1s, 644.8s to go
# on time step 71085 (time=2221.41), 0.0025081 s/step
# Meep progress: 2275.75/10000.0 = 22.8% done in 188.1s, 638.3s to go
# on time step 72844 (time=2276.38), 0.00227523 s/step
# Meep progress: 2332.3125/10000.0 = 23.3% done in 192.1s, 631.4s to go
# on time step 74654 (time=2332.94), 0.00221074 s/step
# Meep progress: 2386.0625/10000.0 = 23.9% done in 196.1s, 625.7s to go
# on time step 76375 (time=2386.72), 0.00232528 s/step
# Meep progress: 2441.1875/10000.0 = 24.4% done in 200.1s, 619.5s to go
# on time step 78138 (time=2441.81), 0.00226918 s/step
# Meep progress: 2492.71875/10000.0 = 24.9% done in 204.1s, 614.6s to go
# on time step 79788 (time=2493.38), 0.00242506 s/step
# Meep progress: 2543.59375/10000.0 = 25.4% done in 208.1s, 610.0s to go
# on time step 81415 (time=2544.22), 0.00245943 s/step
# Meep progress: 2596.5/10000.0 = 26.0% done in 212.1s, 604.7s to go
# on time step 83109 (time=2597.16), 0.00236158 s/step
# Meep progress: 2634.5/10000.0 = 26.3% done in 216.1s, 604.2s to go
# on time step 84308 (time=2634.62), 0.00333719 s/step
# Meep progress: 2685.21875/10000.0 = 26.9% done in 220.1s, 599.6s to go
# on time step 85932 (time=2685.38), 0.00246738 s/step
# Meep progress: 2714.21875/10000.0 = 27.1% done in 224.1s, 601.6s to go
# on time step 86872 (time=2714.75), 0.00425708 s/step
# Meep progress: 2716.59375/10000.0 = 27.2% done in 4206.7s, 11278.6s to go
# on time step 86931 (time=2716.59), 67.5016 s/step
# Meep progress: 2734.5625/10000.0 = 27.3% done in 4210.7s, 11187.5s to go
# on time step 87506 (time=2734.56), 0.00695878 s/step
# Meep progress: 2783.3125/10000.0 = 27.8% done in 4214.7s, 10928.2s to go
# on time step 89067 (time=2783.34), 0.00256369 s/step
# Meep progress: 2835.6875/10000.0 = 28.4% done in 4218.7s, 10658.6s to go
# on time step 90743 (time=2835.72), 0.002387 s/step
# Meep progress: 2893.75/10000.0 = 28.9% done in 4222.7s, 10369.9s to go
# on time step 92602 (time=2893.81), 0.00215253 s/step
# Meep progress: 2950.5/10000.0 = 29.5% done in 4226.7s, 10098.8s to go
# on time step 94417 (time=2950.53), 0.0022055 s/step
# Meep progress: 3003.5/10000.0 = 30.0% done in 4230.8s, 9855.3s to go
# on time step 96115 (time=3003.59), 0.00235715 s/step
# Meep progress: 3061.5/10000.0 = 30.6% done in 4234.8s, 9597.5s to go
# on time step 97971 (time=3061.59), 0.00215592 s/step
# Meep progress: 3119.3125/10000.0 = 31.2% done in 4238.8s, 9350.0s to go
# on time step 99822 (time=3119.44), 0.00216214 s/step
# Meep progress: 3166.75/10000.0 = 31.7% done in 4242.8s, 9155.1s to go
# on time step 101340 (time=3166.88), 0.00263606 s/step
# Meep progress: 3219.625/10000.0 = 32.2% done in 4246.8s, 8943.5s to go
# on time step 103032 (time=3219.75), 0.00236501 s/step
# Meep progress: 3272.90625/10000.0 = 32.7% done in 4250.8s, 8737.0s to go
# on time step 104738 (time=3273.06), 0.00234493 s/step
# Meep progress: 3329.15625/10000.0 = 33.3% done in 4254.8s, 8525.5s to go
# on time step 106539 (time=3329.34), 0.00222158 s/step
# Meep progress: 3381.59375/10000.0 = 33.8% done in 4258.8s, 8335.2s to go
# on time step 108213 (time=3381.66), 0.00239225 s/step
# Meep progress: 3421.8125/10000.0 = 34.2% done in 4262.8s, 8194.9s to go
# on time step 109505 (time=3422.03), 0.00309684 s/step
# Meep progress: 3477.4375/10000.0 = 34.8% done in 4266.8s, 8003.1s to go
# on time step 111286 (time=3477.69), 0.00224659 s/step
# Meep progress: 3532.28125/10000.0 = 35.3% done in 4270.8s, 7819.9s to go
# on time step 113042 (time=3532.56), 0.00227858 s/step
# Meep progress: 3590.46875/10000.0 = 35.9% done in 4274.8s, 7631.1s to go
# on time step 114904 (time=3590.75), 0.00214949 s/step
# Meep progress: 3648.25/10000.0 = 36.5% done in 4278.8s, 7449.5s to go
# on time step 116754 (time=3648.56), 0.00216284 s/step
# Meep progress: 3704.84375/10000.0 = 37.0% done in 4282.8s, 7277.1s to go
# on time step 118562 (time=3705.06), 0.0022162 s/step
# Meep progress: 3754.40625/10000.0 = 37.5% done in 4286.8s, 7131.2s to go
# on time step 120152 (time=3754.75), 0.00251626 s/step
# Meep progress: 3804.96875/10000.0 = 38.0% done in 4290.8s, 6986.0s to go
# on time step 121770 (time=3805.31), 0.0024736 s/step
# Meep progress: 3857.9375/10000.0 = 38.6% done in 4294.8s, 6837.5s to go
# on time step 123468 (time=3858.38), 0.00235655 s/step
# Meep progress: 3899.0/10000.0 = 39.0% done in 4298.8s, 6726.5s to go
# on time step 124774 (time=3899.19), 0.00306372 s/step
# Meep progress: 3949.9375/10000.0 = 39.5% done in 4302.8s, 6590.5s to go
# on time step 126414 (time=3950.44), 0.00244006 s/step
# Meep progress: 4003.59375/10000.0 = 40.0% done in 4306.8s, 6450.5s to go
# on time step 128132 (time=4004.12), 0.00232883 s/step
# Meep progress: 4055.375/10000.0 = 40.6% done in 4310.8s, 6319.0s to go
# on time step 129785 (time=4055.78), 0.00242253 s/step
# Meep progress: 4109.65625/10000.0 = 41.1% done in 4314.8s, 6184.3s to go
# on time step 131527 (time=4110.22), 0.002297 s/step
# Meep progress: 4165.75/10000.0 = 41.7% done in 4318.8s, 6048.6s to go
# on time step 133323 (time=4166.34), 0.00222739 s/step
# Meep progress: 4219.28125/10000.0 = 42.2% done in 4322.8s, 5922.5s to go
# on time step 135037 (time=4219.91), 0.00233411 s/step
# Meep progress: 4272.65625/10000.0 = 42.7% done in 4326.8s, 5799.9s to go
# on time step 136738 (time=4273.06), 0.00235158 s/step
# Meep progress: 4326.6875/10000.0 = 43.3% done in 4330.8s, 5678.7s to go
# on time step 138472 (time=4327.25), 0.00230684 s/step
# Meep progress: 4381.96875/10000.0 = 43.8% done in 4334.8s, 5557.5s to go
# on time step 140242 (time=4382.56), 0.00226091 s/step
# Meep progress: 4435.875/10000.0 = 44.4% done in 4338.8s, 5442.3s to go
# on time step 141967 (time=4436.47), 0.00232011 s/step
# Meep progress: 4490.3125/10000.0 = 44.9% done in 4342.8s, 5328.7s to go
# on time step 143710 (time=4490.94), 0.00229602 s/step
# Meep progress: 4548.40625/10000.0 = 45.5% done in 4346.8s, 5209.9s to go
# on time step 145571 (time=4549.09), 0.00214965 s/step
# Meep progress: 4606.4375/10000.0 = 46.1% done in 4350.8s, 5094.2s to go
# on time step 147427 (time=4607.09), 0.00215607 s/step
# Meep progress: 4661.8125/10000.0 = 46.6% done in 4354.8s, 4986.6s to go
# on time step 149201 (time=4662.53), 0.00225555 s/step
# Meep progress: 4720.4375/10000.0 = 47.2% done in 4358.8s, 4875.1s to go
# on time step 151079 (time=4721.22), 0.0021302 s/step
# Meep progress: 4778.375/10000.0 = 47.8% done in 4362.8s, 4767.5s to go
# on time step 152931 (time=4779.09), 0.00216009 s/step
# Meep progress: 4837.125/10000.0 = 48.4% done in 4366.8s, 4660.9s to go
# on time step 154812 (time=4837.88), 0.0021273 s/step
# Meep progress: 4895.71875/10000.0 = 49.0% done in 4370.8s, 4557.0s to go
# on time step 156687 (time=4896.47), 0.00213345 s/step
# Meep progress: 4951.5/10000.0 = 49.5% done in 4374.8s, 4460.5s to go
# on time step 158473 (time=4952.28), 0.00224046 s/step
# Meep progress: 5010.09375/10000.0 = 50.1% done in 4378.8s, 4361.1s to go
# on time step 160348 (time=5010.88), 0.00213383 s/step
# Meep progress: 5068.96875/10000.0 = 50.7% done in 4382.8s, 4263.5s to go
# on time step 162233 (time=5069.78), 0.0021225 s/step
# Meep progress: 5127.34375/10000.0 = 51.3% done in 4386.8s, 4168.9s to go
# on time step 164100 (time=5128.12), 0.00214342 s/step
# Meep progress: 5186.0/10000.0 = 51.9% done in 4390.8s, 4075.8s to go
# on time step 165976 (time=5186.75), 0.00213286 s/step
# Meep progress: 5246.09375/10000.0 = 52.5% done in 4394.8s, 3982.5s to go
# on time step 167901 (time=5246.91), 0.00207837 s/step
# Meep progress: 5306.375/10000.0 = 53.1% done in 4398.8s, 3890.9s to go
# on time step 169831 (time=5307.22), 0.00207328 s/step
# Meep progress: 5366.53125/10000.0 = 53.7% done in 4402.8s, 3801.4s to go
# on time step 171756 (time=5367.38), 0.00207871 s/step
# Meep progress: 5426.8125/10000.0 = 54.3% done in 4406.8s, 3713.6s to go
# on time step 173687 (time=5427.72), 0.00207155 s/step
# Meep progress: 5483.125/10000.0 = 54.8% done in 4410.8s, 3633.5s to go
# on time step 175474 (time=5483.56), 0.00223855 s/step
# Meep progress: 5541.75/10000.0 = 55.4% done in 4414.8s, 3551.6s to go
# on time step 177365 (time=5542.66), 0.00211551 s/step
# Meep progress: 5601.71875/10000.0 = 56.0% done in 4418.8s, 3469.5s to go
# on time step 179286 (time=5602.69), 0.0020831 s/step
# Meep progress: 5658.03125/10000.0 = 56.6% done in 4422.8s, 3394.1s to go
# on time step 181087 (time=5658.97), 0.00222182 s/step
# Meep progress: 5718.375/10000.0 = 57.2% done in 4426.8s, 3314.6s to go
# on time step 183019 (time=5719.34), 0.00207134 s/step
# Meep progress: 5779.59375/10000.0 = 57.8% done in 4430.8s, 3235.5s to go
# on time step 184980 (time=5780.62), 0.00203985 s/step
# Meep progress: 5840.21875/10000.0 = 58.4% done in 4434.8s, 3158.8s to go
# on time step 186917 (time=5841.16), 0.00206518 s/step
# Meep progress: 5901.0/10000.0 = 59.0% done in 4438.8s, 3083.3s to go
# on time step 188863 (time=5901.97), 0.00205648 s/step
# Meep progress: 5961.03125/10000.0 = 59.6% done in 4442.8s, 3010.3s to go
# on time step 190784 (time=5962), 0.00208302 s/step
# Meep progress: 6021.375/10000.0 = 60.2% done in 4446.8s, 2938.2s to go
# on time step 192715 (time=6022.34), 0.00207242 s/step
# Meep progress: 6081.71875/10000.0 = 60.8% done in 4450.8s, 2867.5s to go
# on time step 194647 (time=6082.72), 0.00207155 s/step
# Meep progress: 6142.9375/10000.0 = 61.4% done in 4454.8s, 2797.1s to go
# on time step 196606 (time=6143.94), 0.00204221 s/step
# Meep progress: 6203.59375/10000.0 = 62.0% done in 4458.8s, 2728.7s to go
# on time step 198547 (time=6204.59), 0.00206117 s/step
# Meep progress: 6264.5/10000.0 = 62.6% done in 4462.8s, 2661.2s to go
# on time step 200495 (time=6265.47), 0.0020536 s/step
# Meep progress: 6324.90625/10000.0 = 63.2% done in 4466.8s, 2595.5s to go
# on time step 202428 (time=6325.88), 0.00206961 s/step
# Meep progress: 6385.15625/10000.0 = 63.9% done in 4470.8s, 2531.1s to go
# on time step 204357 (time=6386.16), 0.00207408 s/step
# Meep progress: 6442.09375/10000.0 = 64.4% done in 4474.8s, 2471.4s to go
# on time step 206178 (time=6443.06), 0.00219714 s/step
# Meep progress: 6496.0/10000.0 = 65.0% done in 4478.8s, 2415.9s to go
# on time step 207899 (time=6496.84), 0.00232566 s/step
# Meep progress: 6539.15625/10000.0 = 65.4% done in 4482.8s, 2372.5s to go
# on time step 209281 (time=6540.03), 0.00289589 s/step
# Meep progress: 6587.21875/10000.0 = 65.9% done in 4486.8s, 2324.6s to go
# on time step 210822 (time=6588.19), 0.00259705 s/step
# Meep progress: 6641.375/10000.0 = 66.4% done in 4490.8s, 2271.1s to go
# on time step 212561 (time=6642.53), 0.00230083 s/step
# Meep progress: 6698.5/10000.0 = 67.0% done in 4494.8s, 2215.4s to go
# on time step 214388 (time=6699.62), 0.00218945 s/step
# Meep progress: 6756.71875/10000.0 = 67.6% done in 4498.8s, 2159.5s to go
# on time step 216250 (time=6757.81), 0.00214869 s/step
# Meep progress: 6806.6875/10000.0 = 68.1% done in 4502.8s, 2112.5s to go
# on time step 217836 (time=6807.38), 0.00252335 s/step
# Meep progress: 6857.3125/10000.0 = 68.6% done in 4506.8s, 2065.5s to go
# on time step 219467 (time=6858.34), 0.00245308 s/step
# Meep progress: 6911.09375/10000.0 = 69.1% done in 4510.8s, 2016.1s to go
# on time step 221189 (time=6912.16), 0.00232356 s/step
# Meep progress: 6965.625/10000.0 = 69.7% done in 4514.8s, 1966.8s to go
# on time step 222936 (time=6966.75), 0.00229032 s/step
# Meep progress: 7020.40625/10000.0 = 70.2% done in 4518.8s, 1917.9s to go
# on time step 224689 (time=7021.53), 0.00228335 s/step
# Meep progress: 7071.375/10000.0 = 70.7% done in 4522.8s, 1873.1s to go
# on time step 226323 (time=7072.59), 0.00244822 s/step
# Meep progress: 7124.9375/10000.0 = 71.2% done in 4526.8s, 1826.7s to go
# on time step 228017 (time=7125.53), 0.00236273 s/step
# Meep progress: 7172.46875/10000.0 = 71.7% done in 4530.8s, 1786.1s to go
# on time step 229557 (time=7173.66), 0.0025982 s/step
# Meep progress: 7222.34375/10000.0 = 72.2% done in 4534.8s, 1744.1s to go
# on time step 231141 (time=7223.16), 0.00252646 s/step
# Meep progress: 7272.40625/10000.0 = 72.7% done in 4538.8s, 1702.3s to go
# on time step 232740 (time=7273.12), 0.00250276 s/step
# Meep progress: 7320.625/10000.0 = 73.2% done in 4542.8s, 1662.7s to go
# on time step 234291 (time=7321.59), 0.00257944 s/step
# Meep progress: 7377.15625/10000.0 = 73.8% done in 4546.8s, 1616.6s to go
# on time step 236095 (time=7377.97), 0.0022177 s/step
# Meep progress: 7429.5/10000.0 = 74.3% done in 4550.8s, 1574.5s to go
# on time step 237778 (time=7430.56), 0.00237724 s/step
# Meep progress: 7482.46875/10000.0 = 74.8% done in 4554.8s, 1532.5s to go
# on time step 239475 (time=7483.59), 0.00235828 s/step
# Meep progress: 7531.0625/10000.0 = 75.3% done in 4558.9s, 1494.5s to go
# on time step 241022 (time=7531.94), 0.00258678 s/step
# Meep progress: 7580.25/10000.0 = 75.8% done in 4562.9s, 1456.5s to go
# on time step 242606 (time=7581.44), 0.00252603 s/step
# Meep progress: 7635.53125/10000.0 = 76.4% done in 4566.9s, 1414.2s to go
# on time step 244377 (time=7636.78), 0.00226023 s/step
# Meep progress: 7691.5/10000.0 = 76.9% done in 4570.9s, 1371.9s to go
# on time step 246167 (time=7692.72), 0.00223521 s/step
# Meep progress: 7746.78125/10000.0 = 77.5% done in 4574.9s, 1330.6s to go
# on time step 247937 (time=7748.03), 0.00226101 s/step
# Meep progress: 7802.53125/10000.0 = 78.0% done in 4578.9s, 1289.6s to go
# on time step 249722 (time=7803.81), 0.00224093 s/step
# Meep progress: 7857.9375/10000.0 = 78.6% done in 4582.9s, 1249.3s to go
# on time step 251495 (time=7859.22), 0.00225679 s/step
# Meep progress: 7912.5/10000.0 = 79.1% done in 4586.9s, 1210.1s to go
# on time step 253240 (time=7913.75), 0.00229268 s/step
# Meep progress: 7966.625/10000.0 = 79.7% done in 4590.9s, 1171.8s to go
# on time step 254972 (time=7967.88), 0.00230952 s/step
# Meep progress: 8018.03125/10000.0 = 80.2% done in 4594.9s, 1135.8s to go
# on time step 256619 (time=8019.34), 0.00242938 s/step
# Meep progress: 8068.8125/10000.0 = 80.7% done in 4598.9s, 1100.7s to go
# on time step 258240 (time=8070), 0.00246815 s/step
# Meep progress: 8120.5625/10000.0 = 81.2% done in 4602.9s, 1065.3s to go
# on time step 259893 (time=8121.66), 0.0024214 s/step
# Meep progress: 8172.375/10000.0 = 81.7% done in 4606.9s, 1030.3s to go
# on time step 261553 (time=8173.53), 0.00241042 s/step
# Meep progress: 8220.84375/10000.0 = 82.2% done in 4610.9s, 997.9s to go
# on time step 263112 (time=8222.25), 0.00256682 s/step
# Meep progress: 8265.71875/10000.0 = 82.7% done in 4614.9s, 968.3s to go
# on time step 264533 (time=8266.66), 0.00281495 s/step
# Meep progress: 8316.875/10000.0 = 83.2% done in 4618.9s, 934.7s to go
# on time step 266183 (time=8318.22), 0.00242426 s/step
# Meep progress: 8360.40625/10000.0 = 83.6% done in 4622.9s, 906.6s to go
# on time step 267570 (time=8361.56), 0.00288448 s/step
# Meep progress: 8411.53125/10000.0 = 84.1% done in 4626.9s, 873.8s to go
# on time step 269211 (time=8412.84), 0.00243837 s/step
# Meep progress: 8463.9375/10000.0 = 84.6% done in 4630.9s, 840.4s to go
# on time step 270873 (time=8464.78), 0.00240736 s/step
# Meep progress: 8515.8125/10000.0 = 85.2% done in 4634.9s, 807.8s to go
# on time step 272549 (time=8517.16), 0.00238667 s/step
# Meep progress: 8566.59375/10000.0 = 85.7% done in 4638.9s, 776.2s to go
# on time step 274176 (time=8568), 0.00246047 s/step
# Meep progress: 8616.0/10000.0 = 86.2% done in 4642.9s, 745.8s to go
# on time step 275758 (time=8617.44), 0.0025296 s/step
# Meep progress: 8666.65625/10000.0 = 86.7% done in 4646.9s, 714.9s to go
# on time step 277378 (time=8668.06), 0.00246953 s/step
# Meep progress: 8719.5625/10000.0 = 87.2% done in 4650.9s, 683.0s to go
# on time step 279072 (time=8721), 0.00236242 s/step
# Meep progress: 8768.96875/10000.0 = 87.7% done in 4654.9s, 653.5s to go
# on time step 280640 (time=8770), 0.00255172 s/step
# Meep progress: 8818.21875/10000.0 = 88.2% done in 4658.9s, 624.4s to go
# on time step 282228 (time=8819.62), 0.00251908 s/step
# Meep progress: 8869.15625/10000.0 = 88.7% done in 4662.9s, 594.5s to go
# on time step 283860 (time=8870.62), 0.00245102 s/step
# Meep progress: 8922.34375/10000.0 = 89.2% done in 4666.9s, 563.7s to go
# on time step 285561 (time=8923.78), 0.00235163 s/step
# Meep progress: 8974.15625/10000.0 = 89.7% done in 4670.9s, 533.9s to go
# on time step 287219 (time=8975.59), 0.00241305 s/step
# Meep progress: 9029.6875/10000.0 = 90.3% done in 4674.9s, 502.4s to go
# on time step 288998 (time=9031.19), 0.00224892 s/step
# Meep progress: 9085.15625/10000.0 = 90.9% done in 4678.9s, 471.1s to go
# on time step 290773 (time=9086.66), 0.00225436 s/step
# Meep progress: 9140.53125/10000.0 = 91.4% done in 4682.9s, 440.3s to go
# on time step 292545 (time=9142.03), 0.00225762 s/step
# Meep progress: 9195.71875/10000.0 = 92.0% done in 4686.9s, 409.9s to go
# on time step 294310 (time=9197.19), 0.00226678 s/step
# Meep progress: 9251.28125/10000.0 = 92.5% done in 4690.9s, 379.6s to go
# on time step 296088 (time=9252.75), 0.00224982 s/step
# Meep progress: 9307.25/10000.0 = 93.1% done in 4694.9s, 349.4s to go
# on time step 297880 (time=9308.75), 0.0022331 s/step
# Meep progress: 9362.34375/10000.0 = 93.6% done in 4698.9s, 320.0s to go
# on time step 299641 (time=9363.78), 0.00227249 s/step
# Meep progress: 9414.09375/10000.0 = 94.1% done in 4702.9s, 292.7s to go
# on time step 301301 (time=9415.66), 0.0024108 s/step
# Meep progress: 9467.09375/10000.0 = 94.7% done in 4706.9s, 265.0s to go
# on time step 302994 (time=9468.56), 0.00236462 s/step
# Meep progress: 9516.15625/10000.0 = 95.2% done in 4710.9s, 239.5s to go
# on time step 304560 (time=9517.5), 0.00255451 s/step
# Meep progress: 9563.96875/10000.0 = 95.6% done in 4714.9s, 215.0s to go
# on time step 306099 (time=9565.59), 0.00260009 s/step
# Meep progress: 9618.34375/10000.0 = 96.2% done in 4718.9s, 187.2s to go
# on time step 307840 (time=9620), 0.0022985 s/step
# Meep progress: 9673.8125/10000.0 = 96.7% done in 4722.9s, 159.2s to go
# on time step 309613 (time=9675.41), 0.00225716 s/step
# Meep progress: 9726.6875/10000.0 = 97.3% done in 4726.9s, 132.8s to go
# on time step 311305 (time=9728.28), 0.00236418 s/step
# Meep progress: 9780.90625/10000.0 = 97.8% done in 4730.9s, 106.0s to go
# on time step 313042 (time=9782.56), 0.0023037 s/step
# Meep progress: 9836.1875/10000.0 = 98.4% done in 4734.9s, 78.9s to go
# on time step 314812 (time=9837.88), 0.00226086 s/step
# Meep progress: 9891.90625/10000.0 = 98.9% done in 4738.9s, 51.8s to go
# on time step 316592 (time=9893.5), 0.00224738 s/step
# Meep progress: 9943.875/10000.0 = 99.4% done in 4742.9s, 26.8s to go
# on time step 318259 (time=9945.59), 0.00240038 s/step
# Meep progress: 9999.28125/10000.0 = 100.0% done in 4746.9s, 0.3s to go
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 400
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
a = 400
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)
