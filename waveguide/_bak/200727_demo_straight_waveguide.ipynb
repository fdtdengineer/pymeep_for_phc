# %%
from pathlib import Path
import os

SCRIPT_DIR = globals().get("SCRIPT_DIR", Path.cwd().parent if Path.cwd().name == "out" else Path.cwd())
FIG_DIR = SCRIPT_DIR / "fig"
OUT_DIR = SCRIPT_DIR / "out"
FIG_DIR.mkdir(exist_ok=True)
OUT_DIR.mkdir(exist_ok=True)
os.chdir(OUT_DIR)

# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
cell = mp.Vector3(16,8,0)

geometry = [mp.Block(mp.Vector3(mp.inf,1,mp.inf),
                     center=mp.Vector3(),
                     material=mp.Medium(epsilon=12))]

sources = [mp.Source(mp.ContinuousSource(frequency=0.15),
                     component=mp.Ez,
                     center=mp.Vector3(-7,0))]

pml_layers = [mp.PML(1.0)]

resolution = 10


sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)

# %%
# %matplotlib inline
plt.figure(dpi=100)
sim.plot2D()
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000129938 s
# Working in 2D dimensions.
# Computational cell is 16 x 8 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0435529 s
# -----------

# %%
sim.run(until=200)

plt.figure(dpi=100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# run 0 finished at t = 200.0 (4000 timesteps)

# %%
T=0.1

sim.reset_meep()
f = plt.figure(dpi=100)
Animate = mp.Animate2D(sim, fields=mp.Ez, f=f, realtime=False, normalize=True)
sim.run(mp.at_every(T,Animate),until=T*200)
plt.close()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000408888 s
# Working in 2D dimensions.
# Computational cell is 16 x 8 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0627069 s
# -----------
# Normalizing field data...
# run 1 finished at t = 20.0 (400 timesteps)

# %%
#Animate.to_gif(10,FIG_DIR / "test.gif")

filename = OUT_DIR / "straight_waveguide.mp4"
Animate.to_mp4(10,filename)
# Out:
# Generating MP4...

# %%
from IPython.display import Video
Video(filename)
# Out:
# <video src="straight_waveguide.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# pngにプロット

T = 0.1
N = 100
#sim.use_output_directory()
sim.run(mp.at_every(T , mp.output_png(mp.Ez, "-Zc dkbluered")), until=N*T)
# Out:
# creating output file "./ez-000020.00.h5"...
# on time step 400 (time=20), 0.119503 s/step
# creating output file "./ez-000020.10.h5"...
# creating output file "./ez-000020.20.h5"...
# creating output file "./ez-000020.30.h5"...
# creating output file "./ez-000020.40.h5"...
# creating output file "./ez-000020.50.h5"...
# creating output file "./ez-000020.60.h5"...
# creating output file "./ez-000020.70.h5"...
# creating output file "./ez-000020.80.h5"...
# creating output file "./ez-000020.90.h5"...
# creating output file "./ez-000021.00.h5"...
# creating output file "./ez-000021.10.h5"...
# creating output file "./ez-000021.20.h5"...
# creating output file "./ez-000021.30.h5"...
# creating output file "./ez-000021.40.h5"...
# creating output file "./ez-000021.50.h5"...
# creating output file "./ez-000021.60.h5"...
# creating output file "./ez-000021.70.h5"...
# creating output file "./ez-000021.80.h5"...
# creating output file "./ez-000021.90.h5"...
# creating output file "./ez-000022.00.h5"...
# creating output file "./ez-000022.10.h5"...
# creating output file "./ez-000022.20.h5"...
# creating output file "./ez-000022.30.h5"...
# Meep progress: 2.3000000000000007/30.0 = 7.7% done in 4.1s, 49.9s to go
# creating output file "./ez-000022.40.h5"...
# on time step 448 (time=22.4), 0.0861961 s/step
# creating output file "./ez-000022.50.h5"...
# creating output file "./ez-000022.60.h5"...
# creating output file "./ez-000022.70.h5"...
# creating output file "./ez-000022.80.h5"...
# creating output file "./ez-000022.90.h5"...
# creating output file "./ez-000023.00.h5"...
# creating output file "./ez-000023.10.h5"...
# creating output file "./ez-000023.20.h5"...
# creating output file "./ez-000023.30.h5"...
# creating output file "./ez-000023.40.h5"...
# creating output file "./ez-000023.50.h5"...
# creating output file "./ez-000023.60.h5"...
# creating output file "./ez-000023.70.h5"...
# creating output file "./ez-000023.80.h5"...
# creating output file "./ez-000023.90.h5"...
# creating output file "./ez-000024.00.h5"...
# creating output file "./ez-000024.10.h5"...
# creating output file "./ez-000024.20.h5"...
# creating output file "./ez-000024.30.h5"...
# creating output file "./ez-000024.40.h5"...
# creating output file "./ez-000024.50.h5"...
# creating output file "./ez-000024.60.h5"...
# creating output file "./ez-000024.70.h5"...
# Meep progress: 4.700000000000003/30.0 = 15.7% done in 8.2s, 44.2s to go
# creating output file "./ez-000024.80.h5"...
# creating output file "./ez-000024.90.h5"...
# on time step 498 (time=24.9), 0.0821466 s/step
# creating output file "./ez-000025.00.h5"...
# creating output file "./ez-000025.10.h5"...
# creating output file "./ez-000025.20.h5"...
# creating output file "./ez-000025.30.h5"...
# creating output file "./ez-000025.40.h5"...
# creating output file "./ez-000025.50.h5"...
# creating output file "./ez-000025.60.h5"...
# creating output file "./ez-000025.70.h5"...
# creating output file "./ez-000025.80.h5"...
# creating output file "./ez-000025.90.h5"...
# creating output file "./ez-000026.00.h5"...
# creating output file "./ez-000026.10.h5"...
# creating output file "./ez-000026.20.h5"...
# creating output file "./ez-000026.30.h5"...
# creating output file "./ez-000026.40.h5"...
# creating output file "./ez-000026.50.h5"...
# creating output file "./ez-000026.60.h5"...
# creating output file "./ez-000026.70.h5"...
# creating output file "./ez-000026.80.h5"...
# creating output file "./ez-000026.90.h5"...
# creating output file "./ez-000027.00.h5"...
# creating output file "./ez-000027.10.h5"...
# creating output file "./ez-000027.20.h5"...
# creating output file "./ez-000027.30.h5"...
# creating output file "./ez-000027.40.h5"...
# creating output file "./ez-000027.50.h5"...
# creating output file "./ez-000027.60.h5"...
# creating output file "./ez-000027.70.h5"...
# creating output file "./ez-000027.80.h5"...
# creating output file "./ez-000027.90.h5"...
# creating output file "./ez-000028.00.h5"...
# Meep progress: 8.0/30.0 = 26.7% done in 12.3s, 33.8s to go
# creating output file "./ez-000028.10.h5"...
# creating output file "./ez-000028.20.h5"...
# on time step 564 (time=28.2), 0.0626708 s/step
# creating output file "./ez-000028.30.h5"...
# creating output file "./ez-000028.40.h5"...
# creating output file "./ez-000028.50.h5"...
# creating output file "./ez-000028.60.h5"...
# creating output file "./ez-000028.70.h5"...
# creating output file "./ez-000028.80.h5"...
# creating output file "./ez-000028.90.h5"...
# creating output file "./ez-000029.00.h5"...
# creating output file "./ez-000029.10.h5"...
# creating output file "./ez-000029.20.h5"...
# creating output file "./ez-000029.30.h5"...
# creating output file "./ez-000029.40.h5"...
# creating output file "./ez-000029.50.h5"...
# creating output file "./ez-000029.60.h5"...
# creating output file "./ez-000029.70.h5"...
# creating output file "./ez-000029.80.h5"...
# creating output file "./ez-000029.90.h5"...
# creating output file "./ez-000030.00.h5"...
# run 2 finished at t = 30.0 (600 timesteps)

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
#plt.axis('off')
plt.show()

# %%
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure()
#plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
#plt.axis('off')
plt.show()
